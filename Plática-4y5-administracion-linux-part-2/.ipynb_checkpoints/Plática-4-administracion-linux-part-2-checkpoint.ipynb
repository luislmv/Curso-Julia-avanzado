# %% [markdown]
# # Tópicos avanzados de programación con Julia

# %% [markdown]
# ## _Sistemas Operativos (Continuación)_

# %% [markdown]
# ### Temario para cubrir el objetivo 1

# %% [markdown]
# __Recomendaciones generales y buenas prácticas al crear el entorno de desarrollo.__
# - Sistemas operativo.
#   - Administración básica de sistemas GNU/Linux.
#     - Gestión de aplicaciones
#       - Tipo de instalaciones.
#       - Ejemplo de instalación desde el código fuente (Maxima).
#       - Ejemplo de instalación desde un binario.
#       - Ejemplo de instalación desde un shell scrip (Anaconda)
#       - Instalación desde paquetes .deb
#         - Conceptos básicos.
#         - Tabla comparativa entre las distintas interfaces de APT.
#         - Instalar y desinstalar paquetes .deb.
#       - Gestión de repositorios.
#         - Añadir repositorios.
#         - Eliminar repositorios.
#         - Instalar desde repositorios (Atom).
#       - Instalación de aplicaciones portables (Julia).
#         - Modificar la variable de entorno PATH.
#         - Modificar la variable de entorno PATH permanentemente.
#         - Crear lanzadores para Julia, Anaconda y Jupyter.
#       - Apartado especial (inodos, enlaces duros y enlaces simbólicos).
#         - Definiciones y ejemplos.
#         - Enlaces simbólicos como alternativa a modificar la variable PATH.
#     - Ejemplos de como se pueden ejecutar cálculos desde Bash con Maxima, Python y Julia.

# %% [markdown]
# ### Administración básica de sistemas GNU/Linux (Continuación)

# %% [markdown]
# Continuamos con la gestión de aplicaciones en GNU/LInux.

# %% [markdown]
# #### Gestión de aplicaciones

# %% [markdown]
# ##### Tipo de instalaciones

# %% [markdown]
# - Aplicaciones portable compiladas o interpretadas.
#   - Se pueden usar sin instalación.
#   - Se puede instalar si se desea.
#     - Se copia a un subdirectorio de __/opt__.
#     - Se añade a la variable de entorno __PATH__ (en un archivo de configuración de bash).
#     - Se crea un lanzador.
# - Obtener el código, compilar e instalar __.tar.gz__.
# - Instalar desde un binario __.bin__, __.run__
#   - Estos son parecidos a los .exe de windows.
#   - No se puede saber que hacen para instalarse.
#   - Generalmente no ofrecen un desintalador.
#   - No se recomienda este tipo de instalaciones.
#   - Usarla sólo si es imprenscindible y si el proveedor es confiable.
# - Instalar desde un shell script __.sh__.
#   - Contiene todos los comandos para que la aplicación quede instalada.
#   - Nosotros podemos crear nuestros propios scripts de bash.
# - Instalar localmente desde un paquete __.deb__.
# - Instalar dede un repositorio (oficial o de terceros) un paquete __.deb__.
# - Instalar paquetes autocontenidos __AppImage__, __Snap__, __Flatpak__ o __Docker__

# %% [markdown]
# ##### Ejemplo de instalación desde el código fuente (Maxima)

# %% [markdown]
# ```bash
# sudo apt install gcl #instalar el intérprete de lisp del proyecto GNU.
# sudo apt install build-essential #instalar los compiladores gcc, g++ y make.
# tar -xzf maxima-5.44.0.tar.gz #desempaquetar y descomprimir.
# ./configure #se comprueban las dependencias y se crea el archivo Makefile desde Makefile.in
# make #Se compila el proyecto con las reglas establecidas en Makefile.
# make check #Esto es opcional. Se ejecutan ciertos test, para verificas que máxima funciona bien.
# sudo make install #Se instala el paquete compilado (similar a apt).
# ```
# Nota
# El comando `make` es de más alto nivel que `gcc` o `g++`, además funciona con más lenguajes de programación. Su utilidad es mayor en proyectos grandes.
#
# Ejemplo:
#
# Para compilar con `gcc`, un proyecto escrito en c (`programa.c`).
# ```c
# #include <stdio.h>
#
# int main (void)
# {
#   printf ("Hola mundo\n");
#   return 0;
# }
# ```
# Con `gcc` (o `cc`):
# ```bash
# gcc programa.c -o programa
# ```
# Con make, sólo hay que ejecutar:
#
# ```bash
# make programa
# ```

# %% [markdown]
# ##### Ejemplo de instalación desde un binario

# %% [markdown]
# ```bash
# sudo ./Tracker-5.1.5-linux-64bit-instaB444ller.run
# sudo ./qt-unified-linux-x64-3.2.3-online.run
# ```

# %% [markdown]
# ##### Ejemplo de instalación desde un shell scrip (Anaconda)

# %% [markdown]
# ```bash
# sudo ./Anaconda3-2020.07-Linux-x86_64.sh #con permisos de ejecución.
# sudo bash Anaconda3-2020.07-Linux-x86_64.sh #no necesita permisos de ejecución.
# ```
# - `-b` (Batch mede).
#   - No modifica el __PATH__ en `~/.bashrc`.
#   - Acepta todo.
#   - Eto elimina la interacción.
# - `-p` (prefix/path)
#   - Para especificar el directorio de instalación.
#   - lo recomendable es que sea en /opt.
# - `-u` (update).
#   - Actualiza si ya está instalado o instala.
#   - Si ya está instalado y no se pone -u, da error.
#
# ```bash
# #Esto hace que todo se instale sin interacción y en el directorio especificado.
# sudo bash Anaconda3-2020.07-Linux-x86_64.sh -ubp /opt/anaconda3/
# sudo bash Anaconda3-2020.07-Linux-x86_64.sh -u -b -p /opt/anaconda3/
# ```

# %% [markdown]
# ##### Instalación desde paquetes .deb

# %% [markdown]
# ###### Conceptos básicos.

# %% [markdown]
# __Paquete__
#
# Un paquete de software es un conjunto de archivos y directorios, que contiene los programas previamente compilados. Incluye sus archivos de configuración. Además, contiene __scripts__ que se ejecutan antes y después de la instalación.
# Este paquete se instala mediante herramientas propias de la distribución.
# Para Debian y derivadas (como Ubuntu) los paquetes se distinguen por  la extensión __.deb__.
#
# __Gestor de paquetes__
#
# El gestor de paquetes es una aplicación de la distribución que nos permite instalar los paquete. Vendría siendo algo parecido a un «intérprete del programa paquete». Esta analogía se debe, a que en el paquete se incluyen las instrucciones para ser instalado y el gestor de paquetes las interpreta y ejecuta.
#
# Algunas de las acciones que realiza el gestor de paquetes pueden ser:
#
# Extraer el contenido y copiarlo en los directorios correspondientes. Comprobar el cumplimiento de dependencias. Ejecutar los scripts de pre instalación y pos instalación, entre otros.
# En Debian y derivadas el gestor de paquetes es dpkg.
#
# __Dependencias__
#
# Una dependencia de software es un conjunto de paquetes necesarios para que otro paquete pueda ser instalado.
# Para poder instalar una aplicación se necesita contar con todas las aplicaciones y bibliotecas que ésta aplicación utiliza para ejecutarse. Esto se conoce como «cumplimiento de dependencias».
#
# __Gestor de dependencias__
#
# Un gestor de dependencias es un software que verifica todas las dependencias de una aplicación y las instala automáticamente para que esta aplicación pueda instalarse y utilizarse.
# En Debian y derivadas e gestor de dependencias es [__APT__](https://es.wikipedia.org/wiki/Advanced_Packaging_Tool).
#
# Las interfaces de __APT__ para la linea de comandos:
# - apt (la más nueva).
# - apt-get (la primera).
# - aptitude (una alternativa más potente que apt-get).
#   - Desde la salida de apt, muchos la han dejado de usar.
#
# También existen interfáces gráficas como Synaptic, Ubuntu software y Gnome Software.
#
# __Repositorio__
#
# Un repositorio es un servidor que ofrece paquetes para ser descargados. Los gestores de dependencias se conectan a estos servidores cuando necesitan obtener una aplicación o alguna dependencia.
#
# Los repositorios pueden ser oficiales o de terceros.
#
# Para poder usar un repositorio, primero hay que añadirlo en un archivo dentro de un directorio concreto. También se necesita colocar la llave pública [__GPG__](https://es.wikipedia.org/wiki/GNU_Privacy_Guard), para establecer una conexión cifrada entre el servidor y el cliente.

# %% [markdown]
# ###### Tabla comparativa entre las distintas interfaces de APT.

# %% [markdown]
# Función|apt-get|aptitude|apt
# :--|:--|:--|:--
# Instalar paquete|`apt-get install app`|`aptitude install app`|`apt install app`
# Desinstalar un paquete|`apt-get remove app`|`aptitude remove app`|`apt remove app`
# Eliminar un paquete y su configuración|`apt-get purge app`|`aptitude purge app`|`apt purge app`
# Actualizar el repositorio|`apt-get update`|`aptitude update`|`apt upate`
# Actualizar paquetes (sin eliminar ni reinstalar)|`apt-get upgrade`|`aptitude safe upgrade`|`apt upgrade` (*)
# Actualizar paquetes (eliminando y reinstalando si es necesario)|`apt-get dist-upgrade`|`aptitude full-upgrade`|`apt full-upgrade`
# Eliminar dependencias innecesarias|`apt-get autoremove`|`aptitude autoremove`|`apt autoremove`
# Buscar paquetes|`apt-cache search app`|`aptitude search app`|`apt search app`
# Mostrar info de un paquete|`apt-cache show app`|`aptitude show app`|`apt show app`
# Mostrar estado y candidato de instalación|`apt-cache policy app`|`aptitude policy app`|`apt policy app`
# Mostrar las fuentes a repositorios|`apt-cache policy`|`aptitude policy`|`apt policy`
# Edición de repositorios fuente|–|–|`apt edit-sources`
# Listar paquetes por criterio|`dpkg –get-selections > lista.txt`|`dpkg –get-selections > lista.txt`|`apt list`

# %% [markdown]
# ###### Instalar y desinstalar paquetes .deb.

# %% [markdown]
# ```bash
# sudo apt install python jupyter #instala los dos paquetes desde repositorios.
# sudo apt install atom-amd64.deb #instala Atom desde un paquete local.
# sudo apt purge python jupyter #desinstala y elimina todos sus archivos de configuración.
# ```

# %% [markdown]
# #####  Gestión de repositorios

# %% [markdown]
# ###### Añadir repositorios

# %% [markdown]
# Para añadir un repositorio, hay que realizar los siguientes pasos.
#
# - Obtener y añadir la llave pública __GPG__.
#   - Se añade mediante el comando `apt-key`.
#   - Las claves se guardan en el archivo `/etc/apt/trusted.gpg` o en el directorio `/etc/apt/trusted.gpg.d/` en archivos independientes con extensión `.gpg`
# - Agregar el repositorio.
#   - Se puede agregar una linea con los datos del repositorio en `/etc/apt/sources.list`.
#   - Crear un archivo en `/etc/apt/sources.list.d/` con extensión `.list` que contenga los datos del repositorio.

# %% [markdown]
# __Primera forma__
#
# El comando (script escrito en python por Canonical) `add-apt-repository` Añade el repositorio e intenta agregar la llave __GPG__ de forma automática. Si el repositorio está en https://launchpad.net/, entonces `add-apt-repository` funciona perfectamente y además ofrece una forma sencilla de añadir el repositorio.
#
# Si el repositorio no está en https://launchpad.net/, lo añadirá, pero seguramente no podrá obtener la llave __GPG__.
#
# _Ejemplo_
#
# Añadir el repositorio estable y actualizado para libreoffice
# ubicado en http://ppa.launchpad.net/libreoffice/ppa/ubuntu
#
# Con este sencillo comando se añade el repositorio:
# ```bash
# sudo add-apt-repository ppa:libreoffice/ppa
# ```
#
# Al ejecutar esto (y teclear `Enter` cuando se solicite), estaremos haciendo varias cosas:
# - Se obtiene la llave publica y se guarda automáticamente.
# - Se crea el archivo `/etc/apt/sources.list.d/libreoffice-ubuntu-ppa-focal.list`
# - Se añaden en dicho archivo, las siguientes lineas:
# ```bash
# deb http://ppa.launchpad.net/libreoffice/ppa/ubuntu focal main
# # deb-src http://ppa.launchpad.net/libreoffice/ppa/ubuntu focal main
# ```
# __Segunda forma__
#
# Añadir el repositorio de Atom ubicado en https://packagecloud.io/AtomEditor/atom
# ```bash
# #Se obtiene la llave GPG con wget y se añade con apt-key en archivo /etc/apt/trusted.gpg.
# wget -qO - https://packagecloud.io/AtomEditor/atom/gpgkey | sudo apt-key add
#
# #Se crea un archivo .list y se escribe la linea deb [arch=amd64] https://packagecloud.io/AtomEditor/atom/any/ any main
# sudo bash -c 'echo "deb [arch=amd64] https://packagecloud.io/AtomEditor/atom/any/ any main" > /etc/apt/sources.list.d/atom.list'
# ```
# _Explicación:_
# ```bash
# #Se descarga el archivo gpgkey de https://packagecloud.io/AtomEditor/atom.
# wget https://packagecloud.io/AtomEditor/atom/gpgkey
#
# #No imprime notificaciones en la salida estándar.
# wget -q https://packagecloud.io/AtomEditor/atom/gpgkey
# #Con -O arch1 descarga gpgkey y lo guarda como arch1.
# wget -O arch1 https://packagecloud.io/AtomEditor/atom/gpgkey
#
# #Con -O - descarga el contenido de gpgkey y lo envía a la salida estándar. Similar a como hace cat. Con este método no se guarda ningún archivo en disco.
# wget -O - https://packagecloud.io/AtomEditor/atom/gpgkey
# ```
# Se puede reunir todo lo anterior en una sola linea:
# ```bash
# #No muestra notificaciones e imprime en pantalla el contenido de gpgkey
# wget -qO - https://packagecloud.io/AtomEditor/atom/gpgkey
# ```
# Con la linea anterior, se obtiene la llave y se imprime en pantalla sin ninguna notificación adicional. Ahora hay que redireccionar la salida a la entrada del comando `sudo apt-key add` mediante una tubería.
# ```bash
# wget -qO - https://packagecloud.io/AtomEditor/atom/gpgkey | sudo apt-key add
# ```
# ```bash
# #Ejecuta la cadena string con bash.
# sudo bash -c string
#
# #Ejecuta con bash echo "deb [arch=amd64] https://packagecloud.io/AtomEditor/atom/any/ any main" > /etc/apt/sources.list.d/atom.list'
# sudo bash -c 'echo "deb [arch=amd64] https://packagecloud.io/AtomEditor/atom/any/ any main" > /etc/apt/sources.list.d/atom.list'
# ```
# Al ejecutar la cadena, `echo` añade la linea `"deb [arch=amd64] https://packagecloud.io/AtomEditor/atom/any/ any main"` en el archivo `/etc/apt/sources.list.d/atom.list`
#
# Si el archivo no existe, entonces lo crea. Si existe, elimina el contenido anterior.
#
# Otra forma de hacer lo anterior sería:
# ```bash
# wget -qO - https://packagecloud.io/AtomEditor/atom/gpgkey | sudo apt-key add
# sudo add-apt-repository "deb [arch=amd64] https://packagecloud.io/AtomEditor/atom/any/ any main"
# ```

# %% [markdown]
# ###### Eliminar repositorios

# %% [markdown]
# Generalmente si se desea eliminar un repositorio, es porque tampoco se desean los paquetes que contiene. En ese caso, se recomiendo desinstalarlos primero, antes de eliminar el repositorio. Luego se puede volver a instalar (si se desea) la versión que está en los repositorios oficiales.
#
# Una forma de hacerlo es borrar el contenido del archivo `.list` dentro del directorio `/etc/apt/sources.list.d/` o simplemente eliminar el archivo.
#
# __IMPORTANTE__
#
# Nunca se debe eliminar el archivo `/etc/apt/sources.list`. Solo los archivos dentro de `/etc/apt/sources.list.d/`.
#
# Si el repositorio se guardó en `/etc/apt/sources.list`, es suficiente con comentar o borrar la linea que corresponde al repositorio.
#
# Este método de comentar, borrar la linea o eliminar un archivo `.list`, no elimina la llave GPG.
#
# Otra forma de eliminar un repositorio es usando el comando
# ```bash
# sudo add-apt-repository --remove
# ```
# Esto borra el contenido del archivo `.list`, pero no al propio archivo. Esto va dejando archivos vacíos en el directorio `/etc/apt/sources.list.d/`. Lo cual puede ser un desventaja.
# Por otra parte, este comando además de eliminar el repositorio, también desinstala sus paquetes y los cambia (si existen) por los que están en los repositorios oficiales.
#
# Ejemplos
# ```bash
# sudo add-apt-repository --remove "deb [arch=amd64] https://packagecloud.io/AtomEditor/atom/any/ any main"
#
# sudo add-apt-repository --remove  ppa:libreoffice/ppa
# ```
# Este método tampoco borra la llave GPG.
#
# Para borrar la llave, se puede hacer los siguiente:
#
# ```bash
# #Muetra una lista de las llaves y su identificador.
# apt-key list
#
# Se copia el id de la clave y ejecuta
#
# #El identificador para atom es 0A0F AB86 0D48 5603 32EF  B581 B754 42BB DE9E 3B09
# sudo apt-key del 0A0F AB86 0D48 5603 32EF  B581 B754 42BB DE9E 3B09
#
# #El identificador para libreoffice es 36E8 1C92 67FD 1383 FCC4  4909 83FB A175 1378 B444
# sudo apt-key del 36E8 1C92 67FD 1383 FCC4  4909 83FB A175 1378 B444
#
# #Si ejecutamos nuevamente apt-key list, ya no están.
# apt-key list
# ```

# %% [markdown]
# ###### Instalar desde repositorios (Atom)

# %% [markdown]
# ```bash
# sudo apt update #actualizamos los índices de cada repositorio añadido.
# sudo apt install atom #si no está instalada.
# sudo apt upgrade #si queremos actualizar todo.
# sudo apt full-upgrade #si queremos hacer una actualización más radical y arriesgada.
# ```

# %% [markdown]
# ##### Instalación de aplicaciones portables (Julia)

# %% [markdown]
# ```bash
# #Nos movemos con cd al directorio que contiene julia-1.5.2-linux-x86_64.tar.gz.
# tar -xzf julia-1.5.2-linux-x86_64.tar.gz
#
# #Creo el directorio jula para poder trabajar con varias versiones.
# sudo mkdir /opt/julia
#
# sudo mv ./julia-1.5.2/ /opt/julia/julia-1.5.2 #Muevo todo al directorio /opt/julia
# ```

# %% [markdown]
# ###### Modificar la variable de entorno PATH

# %%
PATHOLD=$PATH #Guardo antes de modificar.
echo $PATH #antes de añadir.

# %%
PATH+=":/opt/julia/julia-1.5.2/bin" #Añade la ruta de julia a la variable $PATH.

# %%
echo $PATH #después de añadir.

# %%
PATH=$PATHOLD #Recupero el valor inicial.
echo $PATH

# %%
#Modificado manualmente por el administrador
#Añade la ruta hacia julia.
if [[ ! $PATH =~ "/opt/julia/julia-1.5.2/bin" ]]; then
    PATH+=":/opt/julia/julia-1.5.2/bin"
fi

# %%
echo $PATH

# %% [markdown]
# ###### Modificar la variable de entorno PATH permanentemente.

# %% [markdown]
# Existen dos archivos que se ejecutan cada vez que se abre un proceso de shell.
#
# - /etc/bash.bashrc
#   - Archivo de configuración para todos los usuarios.
#   - Se necesita privilegios de root para editarlo.
# - ~/.bashrc
#   - Archivo de configuración local para el usuario actual.
#   - El usuario es dueño y puede modificarlo.
#
# Para que julia esté habilitado basta añadir el siguiente código al final de uno de los dos archivos:
#
# ```bash
# #Modificado manualmente por el administrador
# #Añade la ruta hacia julia.
# if [[ ! $PATH =~ "/opt/julia/julia-1.5.2/bin" ]]; then
#     PATH+=":/opt/julia/julia-1.5.2/bin"
# fi
# ```
#
# Análogamente se puede hacer lo mismo con Anaconda y Jupyter.
#
# ```bash
# #Modificado manualmente por el administrador
# #Añade la ruta hacia Anaconda y Jupyter.
# if [[ ! $PATH =~ "/opt/anaconda3/bin/" ]]; then
#     PATH+=":/opt/anaconda3/bin/"
# fi
# ```

# %% [markdown]
# ###### Crear lanzadores para Julia, Anaconda y Jupyter

# %% [markdown]
# Crear lanzadores para Julia, Anaconda y Jupyter
# Se crea un archivo con extensión `.desktop`. Por ejemplo `Julia.desktop` y se copia en el interior los siguientes campos.
#
# ```bash
# [Desktop Entry]
# Name=Julia
# Icon=/opt/julia/julia-1.5.2/share/doc/julia/html/en/assets/logo-dark.svg
# Exec=/opt/julia/julia-1.5.2/bin/julia
# Terminal=true
# Type=Application
# Categories=Development
# ```
# Si se desea que esté en el menú de aplicaciones se puede copiar a los siguientes archivos:
#
# - `/usr/share/applications`
#   - Para todos los usuarios.
# - `~/.local/share/applications`
#   - Solo para el usuario actual.
# - `/etc/xdg/autostart`
#   - Durante el inicio de sesión.
#
# Análogamente para Anaconda y Jupyter:
#
# En `Anaconda.desktop`
#
# ```bash
# [Desktop Entry]
# Name=Anaconda
# Icon=/opt/anaconda3/lib/python3.8/site-packages/navigator_updater/static/images/anaconda-logo.svg
# Exec=/opt/anaconda3/bin/anaconda-navigator
# Terminal=false
# Type=Application
# Categories=Development
# ```
# En `Jupyter.desktop`
#
# ```bash
# [Desktop Entry]
# Name=Jupyter
# Icon=/opt/anaconda3/lib/python3.8/site-packages/anaconda_navigator/static/images/jupyter-icon-1024x1024.png
# Exec=/opt/anaconda3/bin/jupyter-notebook
# Terminal=false
# Type=Application
# Categories=Development
# ```

# %% [markdown]
# ##### Apartado especial (inodos, enlaces duros y enlaces simbólicos)

# %% [markdown]
# ###### Definiciones y ejemplos

# %% [markdown]
# _Inodos_
# - Un inodo es un tipo de estructura de datos de C.
#   - Cada inodo tiene asociado un número entero único (es su identificador).
#   - Cada archivo del __VFS__ tiene asociado un único inodo.
#   - Un inodo contiene información (los metadatos) de un único archivo (el asociado).
#
# La información que almacena el indodo es:
#
# - El identificador uiversal de la partición (__uuid__).
# - El número de inodo (su propio identificador).
# - La tamaño del archivo en bytes y el número de bloques que ocupa.
# - El identificador (__uid__) del usuario dueño.
# - El identificador (__gid__) del grupo al que pertenece.
# - Los permisos (__r__, __w__ y __x__) del archivo para (__u__, __g__ y __o__).
# - Las marcas de tiempo con las fechas de última modificación (__mtime__), acceso (__atime__) y de alteración del propio inodo (__ctime__).
# - El número de __enlaces duros__, esto es, el número de nombres (entradas de directorio) asociados con este inodo.
# - La estructura de punteros, para direccionar hacia los bloques de datos (que es el contenido) del archivo.

# %%
stat /
# Out:
#   Fichero: /
#   Tamaño: 4096      	Bloques: 8          Bloque E/S: 4096   directorio
# Dispositivo: 10306h/66310d	Nodo-i: 2           Enlaces: 27
# Acceso: (0755/drwxr-xr-x)  Uid: (    0/    root)   Gid: (    0/    root)
# Acceso: 2020-10-29 16:28:22.612339651 -0600
# Modificación: 2020-08-12 03:52:56.940507696 -0500
#       Cambio: 2020-08-12 03:52:56.940507696 -0500
#     Creación: -

# %% [markdown]
# _Enlace duro_
#
# - Un enlace duro, no es más que asociar una etiqueta (el nombsudore del fichero) dentro de un directorio a un número de inodo.
# - En GNU/Linux, es posible asociar más de una etiqueta a un mismo inodo. Por tanto pueden haber varios accesos a un mismo archivo.
#   - El acceso puede estar en el mismo directorio (con otra etiqueta) o en otro directorio __de la misma partición__.
#   - En caso de que esté en otro directorio, la etiqueta que se use es irrelevante. En otras palabras, un mismo archivo puede tener distintos nombres en directorios diferentes.
# - Mediante el comando `ln` se pueden crear más enlaces duros, usando a uno ya existente como referencia.
# - No se pueden crear manualmente enlaces duros a directorios, para evitar contradicciones (el directorio padre puede ser hijo del directorio hijo). El sistema crea automáticamente algunos enlaces duros entre directorios (los directorios `.` sudoy `..` se crean automáticamente dentro de cada directorio).
# - El enlace duro creado a partir de otro, es independiente del «original», es decir, no es más importante el «original» que en nuevo.
# - Los cambios realizados desde un enlace duro afecta al contenido, por lo que el resultado será visible desde cualquier otro enlace duro.
# - Si se elimina uno de los enlaces duros, la información no es liberada, haste que el último enlace duro haya sido eliminado.
#
# Un archivo de tipo directorio es una lista de enlaces duros. En otras palabras, es una tabla que contiene a los números enteros que representan a los indodos junto a sus etiquetas.
#
# _Enlace simbólico_
#
# - Un enlace simbólico, conecta a un archivo con otro, mediante su etiqueta (nombre dentro de algún directorio).
# - En este caso si existe diferencia entre uno y otro.
#   - Si el original cambia de nombre, es movido o eliminado, el enlace simbólico »queda roto», que este desconoce el inodo y por tanto no puede acceder a la información del archivo original.
# - Se pueden crear enlaces simbólicos con `ln -s`. Si son directorios, no es necesaria la opción -s, ya que en este caso sólo se pueden creare enlaces simbólicos.
# - Se pueden crear enlaces simbólicos a archivos presentes en otra particíón e incluso a archivos en equipos remotos.
# - Los enlaces simbólicos, se pueden usar para conectar una aplicación intalada en un directorio que no está en la variable PATH, con otro que sí lo esté.

# %%
ls -liha /
# Out:
# total 2.1G
#       2 drwxr-xr-x  27 root root 4.0K ago 12 03:52 .
#       2 drwxr-xr-x  27 root root 4.0K ago 12 03:52 ..
# 3276801 drwxr-xr-x   2 root root 4.0K oct 26 12:51 bin
# 3014657 drwxr-xr-x   4 root root 4.0K oct 28 16:26 boot
# 1966081 drwxr-xr-x   2 root root 4.0K sep 10  2019 cdrom
# 4194696 drwxr-xr-x   2 root root 4.0K ago 12 03:52 .config
#       2 drwxr-xr-x  22 root root 5.0K oct 29 12:02 dev
# 3671805 drwxr-xr-x   3 root root 4.0K may 15 06:26 .dotnet
# 4325377 drwxr-xr-x 161 root root  12K oct 29 20:30 etc
#       2 drwxr-xr-x   7 root root 4.0K oct 15 21:11 home
#      17 lrwxrwxrwx   1 root root   34 jul 22 17:42 initrd.img -> boot/initrd.img-4.15.0-112-generic
#      16 lrwxrwxrwx   1 root root   34 jul 22 17:42 initrd.img.old -> boot/initrd.img-4.15.0-111-generic
#  393217 drwxr-xr-x  21 root root 4.0K oct  7 11:37 lib
# 3407873 drwxr-xr-x   2 root root 4.0K sep 23 11:05 lib32
# 3670017 drwxr-xr-x   2 root root 4.0K sep 23 11:05 lib64
#      11 drwx------   2 root root  16K sep 10  2019 lost+found
#  262145 drwxr-xr-x   6 root root 4.0K oct 14 12:24 media
# 4718593 drwxr-xr-x   2 root root 4.0K oct 11  2018 mnt
# 3801089 drwxr-xr-x  15 root root 4.0K oct 22 23:23 opt
#       1 dr-xr-xr-x 308 root root    0 oct 29 12:01 proc
#  524289 drwx------  23 root root 4.0K oct 23 03:14 root
#       2 drwxr-xr-x  35 root root 1020 oct 29 12:06 run
# 4849665 drwxr-xr-x   2 root root  12K oct 26 12:51 sbin
# 5242881 drwxr-xr-x  13 root root 4.0K sep 12 04:13 snap
# 1441793 drwxr-xr-x   2 root root 4.0K oct 11  2018 srv
#      12 -rw-------   1 root root 2.0G sep 10  2019 swapfile
#       1 dr-xr-xr-x  13 root root    0 oct 29 12:01 sys
# 1572865 drwxrwxrwt  27 root root  68K oct 30 00:01 tmp
# 4980737 drwxr-xr-x  12 root root 4.0K jun 10 10:11 usr
# 1310721 drwxr-xr-x  12 root root 4.0K oct 11  2018 var
#      18 lrwxrwxrwx   1 root root   31 jul 22 17:42 vmlinuz -> boot/vmlinuz-4.15.0-112-generic
#      13 lrwxrwxrwx   1 root root   31 jul 22 17:42 vmlinuz.old -> boot/vmlinuz-4.15.0-111-generic

# %%
ls -lhia /tmp
# Out:
# total 7.9M
# 1572865 drwxrwxrwt 25 root root  68K oct 29 22:14  .
#       2 drwxr-xr-x 27 root root 4.0K ago 12 03:52  ..
# 1575051 drwx------  2 luis luis 4.0K oct 29 16:28 'Atom Crashes'
# 1575053 srwxrwxr-x  1 luis luis    0 oct 29 17:40  atom-c38dbb295984.sock
# 1584019 drwxrwxr-x  4 luis luis 4.0K oct 29 22:28  dir1
# 1572869 drwxrwxrwt  2 root root 4.0K oct 29 12:01  .font-unix
# 1572880 -rw-r--r--  1 root root 2.1K oct 29 12:01  glances-root.log
# 1572867 drwxrwxrwt  2 root root 4.0K oct 29 12:01  .ICE-unix
# 1573211 drwx------  2 luis luis 4.0K oct 29 16:28  net-export
# 1573203 drwxrwxr-x  2 luis luis 4.0K oct 29 12:01  plasma-csd-generator
# 1572879 drwxr-xr-x  2 plex plex 4.0K oct 29 12:01  pms-97c38591-fff4-4742-bef4-0da9cb802d2e
# 1572950 srwxr-xr-x  1 root root    0 oct 29 12:01  sddm-auth0e4f49d8-0db2-46e9-992f-7820d09a859f
# 1573197 drwx------  2 luis luis 4.0K oct 29 12:01  ssh-f2IbVdNfpXvM
# 1573207 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-bolt.service-uNTypj
# 1573032 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-colord.service-XWKppi
# 1573205 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-fwupd.service-ERndgg
# 1572885 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-haveged.service-1nSIkg
# 1573030 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-ModemManager.service-mq5Muf
# 1572883 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-switcheroo-control.service-rmsLli
# 1572887 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-systemd-logind.service-mSJj1e
# 1572871 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-systemd-resolved.service-E4OHOh
# 1572874 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-systemd-timesyncd.service-fIp1fi
# 1573200 drwx------  3 root root 4.0K oct 29 12:01  systemd-private-8c2f1b0eaff6439fb68c08c39515e81d-upower.service-TNQSmj
# 1573209 drwx------  2 luis luis 4.0K oct 29 12:01  Temp-2c562274-3701-4817-8f30-22a71728e50d
# 1573208 drwx------  2 luis luis 4.0K oct 29 12:01  Temp-707d2b0f-1854-4485-b990-803c227ba399
# 1572870 drwxrwxrwt  2 root root 4.0K oct 29 12:01  .Test-unix
# 1583421 -rw-------  1 luis luis    0 oct 29 21:12  tmp00dqhsx6
# 1580773 -rw-------  1 luis luis    0 oct 29 20:49  tmp01b2e_ct
# 1582159 -rw-------  1 luis luis    0 oct 29 20:59  tmp01s5_nqo
# 1582091 -rw-------  1 luis luis    0 oct 29 20:54  tmp02a4k64c
# 1583631 -rw-------  1 luis luis    0 oct 29 21:26  tmp03whpxxg
# 1583392 -rw-------  1 luis luis    0 oct 29 21:10  tmp0443ackb
# 1582426 -rw-------  1 luis luis    0 oct 29 21:07  tmp04wpculq
# 1582211 -rw-------  1 luis luis    0 oct 29 21:02  tmp060y4tni
# 1583813 -rw-------  1 luis luis    0 oct 29 21:37  tmp07oz14rg
# 1578122 -rw-------  1 luis luis    0 oct 29 20:49  tmp08vteu0w
# 1583944 -rw-------  1 luis luis    0 oct 29 21:45  tmp09zoz8cm
# 1584023 -rw-------  1 luis luis    0 oct 29 21:50  tmp0c0x546l
# 1583836 -rw-------  1 luis luis    0 oct 29 21:38  tmp0eba9vh8
# 1583425 -rw-------  1 luis luis    0 oct 29 21:12  tmp0fizr074
# 1582213 -rw-------  1 luis luis    0 oct 29 21:03  tmp0f_q692r
# 1580943 -rw-------  1 luis luis    0 oct 29 20:53  tmp0fscwf47
# 1584034 -rw-------  1 luis luis    0 oct 29 21:51  tmp0ftlde00
# 1583654 -rw-------  1 luis luis    0 oct 29 21:27  tmp0fvah0br
# 1582225 -rw-------  1 luis luis    0 oct 29 21:03  tmp0haxu2bz
# 1583569 -rw-------  1 luis luis    0 oct 29 21:22  tmp0kp92tki
# 1583770 -rw-------  1 luis luis    0 oct 29 21:34  tmp0rsm398i
# 1580947 -rw-------  1 luis luis    0 oct 29 20:53  tmp0umuhy0y
# 1583619 -rw-------  1 luis luis    0 oct 29 21:25  tmp0unvfgsw
# 1582413 -rw-------  1 luis luis    0 oct 29 21:06  tmp0wb77k1c
# 1582199 -rw-------  1 luis luis    0 oct 29 21:02  tmp0woe424n
# 1583469 -rw-------  1 luis luis    0 oct 29 21:15  tmp1072sg2i
# 1584006 -rw-------  1 luis luis    0 oct 29 21:49  tmp11vl6gjo
# 1583906 -rw-------  1 luis luis    0 oct 29 21:43  tmp12v1a109
# 1580821 -rw-------  1 luis luis    0 oct 29 20:52  tmp194218ud
# 1583512 -rw-------  1 luis luis    0 oct 29 21:18  tmp19u4aalq
# 1575084 -rw-------  1 luis luis    0 oct 29 20:46  tmp1dro8r3z
# 1583683 -rw-------  1 luis luis    0 oct 29 21:30  tmp1e5wamyo
# 1582417 -rw-------  1 luis luis    0 oct 29 21:06  tmp1gt3u17i
# 1580810 -rw-------  1 luis luis    0 oct 29 20:51  tmp1iw0a0ru
# 1583387 -rw-------  1 luis luis    0 oct 29 21:10  tmp1_lzep55
# 1582105 -rw-------  1 luis luis    0 oct 29 20:55  tmp1mjlzd9n
# 1584036 -rw-------  1 luis luis    0 oct 29 21:51  tmp1ngs0cp1
# 1583673 -rw-------  1 luis luis    0 oct 29 21:29  tmp1nv536i6
# 1584002 -rw-------  1 luis luis    0 oct 29 21:49  tmp1ogozp08
# 1584031 -rw-------  1 luis luis    0 oct 29 21:51  tmp1o_h91l0
# 1582253 -rw-------  1 luis luis    0 oct 29 21:05  tmp1p0y17h1
# 1583946 -rw-------  1 luis luis    0 oct 29 21:45  tmp1pq_6b1w
# 1583436 -rw-------  1 luis luis    0 oct 29 21:13  tmp1_qc5ks7
# 1583825 -rw-------  1 luis luis    0 oct 29 21:37  tmp_1qphvg8
# 1582106 -rw-------  1 luis luis    0 oct 29 20:55  tmp1ret8yaz
# 1583412 -rw-------  1 luis luis    0 oct 29 21:11  tmp1ryes7xw
# 1583976 -rw-------  1 luis luis    0 oct 29 21:47  tmp1su7mjlw
# 1583599 -rw-------  1 luis luis    0 oct 29 21:24  tmp1tfoiksu
# 1583973 -rw-------  1 luis luis    0 oct 29 21:47  tmp1uxk2h1y
# 1583380 -rw-------  1 luis luis    0 oct 29 21:09  tmp1v5p0aqn
# 1582237 -rw-------  1 luis luis    0 oct 29 21:04  tmp1vso3ne1
# 1583718 -rw-------  1 luis luis    0 oct 29 21:32  tmp1w1lt22v
# 1583555 -rw-------  1 luis luis    0 oct 29 21:21  tmp1whwxwcn
# 1583466 -rw-------  1 luis luis    0 oct 29 21:15  tmp1wycar86
# 1580766 -rw-------  1 luis luis    0 oct 29 20:49  tmp1xvdu7_p
# 1583656 -rw-------  1 luis luis    0 oct 29 21:28  tmp1z8hsb61
# 1583382 -rw-------  1 luis luis    0 oct 29 21:09  tmp1zxx66sm
# 1582184 -rw-------  1 luis luis    0 oct 29 21:01  tmp20lvj_17
# 1583821 -rw-------  1 luis luis    0 oct 29 21:37  tmp217hh4u1
# 1580806 -rw-------  1 luis luis    0 oct 29 20:51  tmp21lijrj0
# 1583832 -rw-------  1 luis luis    0 oct 29 21:38  tmp21wfmv5u
# 1584007 -rw-------  1 luis luis    0 oct 29 21:50  tmp22q8yrbw
# 1583445 -rw-------  1 luis luis    0 oct 29 21:14  tmp23z5zpjv
# 1583644 -rw-------  1 luis luis    0 oct 29 21:27  tmp26noudjc
# 1575071 -rw-------  1 luis luis    0 oct 29 20:45  tmp26ucxsvh
# 1582175 -rw-------  1 luis luis    0 oct 29 21:00  tmp_278qt1l
# 1582250 -rw-------  1 luis luis    0 oct 29 21:05  tmp27u93j2f
# 1582173 -rw-------  1 luis luis    0 oct 29 21:00  tmp28acyfiv
# 1583403 -rw-------  1 luis luis    0 oct 29 21:11  tmp2aqgaevt
# 1583501 -rw-------  1 luis luis    0 oct 29 21:17  tmp2e48_57d
# 1580768 -rw-------  1 luis luis    0 oct 29 20:49  tmp2iacqyf8
# 1582083 -rw-------  1 luis luis    0 oct 29 20:54  tmp2_igrbd1
# 1582188 -rw-------  1 luis luis    0 oct 29 21:01  tmp2jo31d9s
# 1583945 -rw-------  1 luis luis    0 oct 29 21:45  tmp2kfdb30o
# 1583542 -rw-------  1 luis luis    0 oct 29 21:20  tmp2lbo3x0l
# 1582133 -rw-------  1 luis luis    0 oct 29 20:57  tmp2m9z1l3c
# 1583554 -rw-------  1 luis luis    0 oct 29 21:21  tmp2mgg90g7
# 1583967 -rw-------  1 luis luis    0 oct 29 21:47  tmp2mr8wri1
# 1582229 -rw-------  1 luis luis    0 oct 29 21:04  tmp2n8up3cq
# 1583562 -rw-------  1 luis luis    0 oct 29 21:21  tmp2ndcxn6o
# 1583872 -rw-------  1 luis luis    0 oct 29 21:41  tmp2q5yeu5c
# 1583859 -rw-------  1 luis luis    0 oct 29 21:40  tmp2q91hlut
# 1582434 -rw-------  1 luis luis    0 oct 29 21:08  tmp2rbqcoxe
# 1575067 -rw-------  1 luis luis    0 oct 29 20:45  tmp2rcxga7r
# 1580815 -rw-------  1 luis luis    0 oct 29 20:51  tmp2ri6cxie
# 1583464 -rw-------  1 luis luis    0 oct 29 21:15  tmp2tkwjq1r
# 1583834 -rw-------  1 luis luis    0 oct 29 21:38  tmp2vh72_og
# 1582424 -rw-------  1 luis luis    0 oct 29 21:07  tmp2vkymvt7
# 1583968 -rw-------  1 luis luis    0 oct 29 21:47  tmp2w_k72xy
# 1580794 -rw-------  1 luis luis    0 oct 29 20:50  tmp2wtnki1q
# 1583719 -rw-------  1 luis luis    0 oct 29 21:32  tmp2wtxujku
# 1583842 -rw-------  1 luis luis    0 oct 29 21:38  tmp2ygvy0mq
# 1583456 -rw-------  1 luis luis    0 oct 29 21:14  tmp2yqtggii
# 1583715 -rw-------  1 luis luis    0 oct 29 21:32  tmp2z709yw4
# 1584012 -rw-------  1 luis luis    0 oct 29 21:50  tmp30jycni_
# 1583899 -rw-------  1 luis luis    0 oct 29 21:42  tmp30qhttji
# 1582166 -rw-------  1 luis luis    0 oct 29 20:59  tmp31096boy
# 1575081 -rw-------  1 luis luis    0 oct 29 20:46  tmp33283edo
# 1583486 -rw-------  1 luis luis    0 oct 29 21:16  tmp33h08rzk
# 1583579 -rw-------  1 luis luis    0 oct 29 21:23  tmp33qhy7vi
# 1583731 -rw-------  1 luis luis    0 oct 29 21:33  tmp355vsuw3
# 1582111 -rw-------  1 luis luis    0 oct 29 20:56  tmp37xhr_md
# 1584038 -rw-------  1 luis luis    0 oct 29 21:51  tmp38uz5nk6
# 1583584 -rw-------  1 luis luis    0 oct 29 21:23  tmp3auvfsff
# 1583687 -rw-------  1 luis luis    0 oct 29 21:30  tmp3cnry5g3
# 1583889 -rw-------  1 luis luis    0 oct 29 21:42  tmp3e5_vysb
# 1583722 -rw-------  1 luis luis    0 oct 29 21:32  tmp3ff4mj3f
# 1583526 -rw-------  1 luis luis    0 oct 29 21:19  tmp3fznywis
# 1583536 -rw-------  1 luis luis    0 oct 29 21:20  tmp3ixicinx
# 1583576 -rw-------  1 luis luis    0 oct 29 21:22  tmp3ixy1dpa
# 1582206 -rw-------  1 luis luis    0 oct 29 21:02  tmp3j5_4fga
# 1583447 -rw-------  1 luis luis    0 oct 29 21:14  tmp3js6tie4
# 1583989 -rw-------  1 luis luis    0 oct 29 21:48  tmp3kc3a3dy
# 1582084 -rw-------  1 luis luis    0 oct 29 20:54  tmp3kr3e5qe
# 1583937 -rw-------  1 luis luis    0 oct 29 21:45  tmp3lgyda7c
# 1583564 -rw-------  1 luis luis    0 oct 29 21:22  tmp3mbjkos7
# 1583984 -rw-------  1 luis luis    0 oct 29 21:48  tmp3mi80q6p
# 1583420 -rw-------  1 luis luis    0 oct 29 21:12  tmp3ssg9h2m
# 1583796 -rw-------  1 luis luis    0 oct 29 21:35  tmp3uumr036
# 1580786 -rw-------  1 luis luis    0 oct 29 20:50  tmp3vkpmrp4
# 1583726 -rw-------  1 luis luis    0 oct 29 21:32  tmp3xcy1poa
# 1583769 -rw-------  1 luis luis    0 oct 29 21:34  tmp3ymrjluf
# 1582090 -rw-------  1 luis luis    0 oct 29 20:54  tmp3_z125h7
# 1582181 -rw-------  1 luis luis    0 oct 29 21:01  tmp3z2sew7a
# 1583485 -rw-------  1 luis luis    0 oct 29 21:16  tmp40w3np17
# 1583566 -rw-------  1 luis luis    0 oct 29 21:22  tmp41dfj4n2
# 1583509 -rw-------  1 luis luis    0 oct 29 21:18  tmp42c229sm
# 1583643 -rw-------  1 luis luis    0 oct 29 21:27  tmp43qkdlr5
# 1582153 -rw-------  1 luis luis    0 oct 29 20:59  tmp44jqprwa
# 1583880 -rw-------  1 luis luis    0 oct 29 21:41  tmp44jxgtik
# 1583556 -rw-------  1 luis luis    0 oct 29 21:21  tmp4562bpi3
# 1583680 -rw-------  1 luis luis    0 oct 29 21:29  tmp473hyh1g
# 1582428 -rw-------  1 luis luis    0 oct 29 21:07  tmp48052u2d
# 1582202 -rw-------  1 luis luis    0 oct 29 21:02  tmp49ofgdqt
# 1583941 -rw-------  1 luis luis    0 oct 29 21:45  tmp4a_oc_4g
# 1583792 -rw-------  1 luis luis    0 oct 29 21:35  tmp4d0yp5n_
# 1583871 -rw-------  1 luis luis    0 oct 29 21:41  tmp4dal1va6
# 1583724 -rw-------  1 luis luis    0 oct 29 21:32  tmp4e559ar0
# 1582116 -rw-------  1 luis luis    0 oct 29 20:56  tmp4kying6_
# 1583900 -rw-------  1 luis luis    0 oct 29 21:42  tmp4m7ah5ge
# 1583861 -rw-------  1 luis luis    0 oct 29 21:40  tmp4o19zc2t
# 1583406 -rw-------  1 luis luis    0 oct 29 21:11  tmp4o1eh19g
# 1583723 -rw-------  1 luis luis    0 oct 29 21:32  tmp4ows4dtf
# 1583552 -rw-------  1 luis luis    0 oct 29 21:21  tmp4ox2vtgt
# 1582149 -rw-------  1 luis luis    0 oct 29 20:58  tmp4p3c8n46
# 1575122 -rw-------  1 luis luis    0 oct 29 20:47  tmp4pen92nt
# 1583706 -rw-------  1 luis luis    0 oct 29 21:31  tmp4rb8k_mr
# 1575100 -rw-------  1 luis luis    0 oct 29 20:46  tmp4ufi_ix8
# 1583998 -rw-------  1 luis luis    0 oct 29 21:49  tmp4uk1o125
# 1583532 -rw-------  1 luis luis    0 oct 29 21:19  tmp4va0sq64
# 1580944 -rw-------  1 luis luis    0 oct 29 20:53  tmp4vda1bg6
# 1582174 -rw-------  1 luis luis    0 oct 29 21:00  tmp4w0aqa0n
# 1582151 -rw-------  1 luis luis    0 oct 29 20:58  tmp4wo187_c
# 1584028 -rw-------  1 luis luis    0 oct 29 21:51  tmp4y3zhpl2
# 1583863 -rw-------  1 luis luis    0 oct 29 21:40  tmp_4zxd77k
# 1582437 -rw-------  1 luis luis    0 oct 29 21:08  tmp50q8xz25
# 1583901 -rw-------  1 luis luis    0 oct 29 21:42  tmp536p5xin
# 1583807 -rw-------  1 luis luis    0 oct 29 21:36  tmp55v_4147
# 1583922 -rw-------  1 luis luis    0 oct 29 21:44  tmp563sjivs
# 1582248 -rw-------  1 luis luis    0 oct 29 21:05  tmp59qvdwz5
# 1583431 -rw-------  1 luis luis    0 oct 29 21:13  tmp5bh0x0a3
# 1582423 -rw-------  1 luis luis    0 oct 29 21:07  tmp5cwpdws_
# 1580809 -rw-------  1 luis luis    0 oct 29 20:51  tmp5gzeeyyj
# 1583635 -rw-------  1 luis luis    0 oct 29 21:26  tmp5lva1j5c
# 1583578 -rw-------  1 luis luis    0 oct 29 21:22  tmp5p80nayb
# 1583417 -rw-------  1 luis luis    0 oct 29 21:12  tmp_5pugjqv
# 1583483 -rw-------  1 luis luis    0 oct 29 21:16  tmp5t6f55_h
# 1580780 -rw-------  1 luis luis    0 oct 29 20:50  tmp5u9uugmk
# 1583693 -rw-------  1 luis luis    0 oct 29 21:30  tmp5vdjpi7i
# 1583716 -rw-------  1 luis luis    0 oct 29 21:32  tmp5x1ebyjv
# 1584011 -rw-------  1 luis luis    0 oct 29 21:50  tmp5xpmyohl
# 1583558 -rw-------  1 luis luis    0 oct 29 21:21  tmp5yncyuge
# 1575131 -rw-------  1 luis luis    0 oct 29 20:47  tmp5yqw_031
# 1575069 -rw-------  1 luis luis    0 oct 29 20:45  tmp5zewi2rl
# 1583972 -rw-------  1 luis luis    0 oct 29 21:47  tmp60b6_lmb
# 1583824 -rw-------  1 luis luis    0 oct 29 21:37  tmp60s3abyl
# 1583804 -rw-------  1 luis luis    0 oct 29 21:36  tmp61z8mywa
# 1583565 -rw-------  1 luis luis    0 oct 29 21:22  tmp62k734nx
# 1583596 -rw-------  1 luis luis    0 oct 29 21:24  tmp63fa51f2
# 1583527 -rw-------  1 luis luis    0 oct 29 21:19  tmp63zpqar1
# 1583381 -rw-------  1 luis luis    0 oct 29 21:09  tmp66rqblpg
# 1583992 -rw-------  1 luis luis    0 oct 29 21:49  tmp67z4xji8
# 1582436 -rw-------  1 luis luis    0 oct 29 21:08  tmp6872o2gw
# 1583465 -rw-------  1 luis luis    0 oct 29 21:15  tmp69ulwkx_
# 1583960 -rw-------  1 luis luis    0 oct 29 21:46  tmp6adeo4pm
# 1583488 -rw-------  1 luis luis    0 oct 29 21:17  tmp6amob8o4
# 1582236 -rw-------  1 luis luis    0 oct 29 21:04  tmp6b_tezsl
# 1582246 -rw-------  1 luis luis    0 oct 29 21:05  tmp6cv9z4r3
# 1583481 -rw-------  1 luis luis    0 oct 29 21:16  tmp6e3bjqcs
# 1583473 -rw-------  1 luis luis    0 oct 29 21:15  tmp6e3wgfd7
# 1582204 -rw-------  1 luis luis    0 oct 29 21:02  tmp6g3za_jk
# 1582433 -rw-------  1 luis luis    0 oct 29 21:07  tmp6gw_m2md
# 1583570 -rw-------  1 luis luis    0 oct 29 21:22  tmp6h4g733c
# 1583594 -rw-------  1 luis luis    0 oct 29 21:23  tmp6hfbzwrs
# 1583778 -rw-------  1 luis luis    0 oct 29 21:34  tmp6_k62qrb
# 1583592 -rw-------  1 luis luis    0 oct 29 21:23  tmp6k_tcbyc
# 1582210 -rw-------  1 luis luis    0 oct 29 21:02  tmp6odznw9l
# 1575120 -rw-------  1 luis luis    0 oct 29 20:47  tmp6pfcsw0w
# 1583729 -rw-------  1 luis luis    0 oct 29 21:33  tmp6t6wdmbm
# 1583904 -rw-------  1 luis luis    0 oct 29 21:43  tmp6wd5_trq
# 1583915 -rw-------  1 luis luis    0 oct 29 21:43  tmp6xuhpek5
# 1582411 -rw-------  1 luis luis    0 oct 29 21:06  tmp6ykuz68l
# 1583407 -rw-------  1 luis luis    0 oct 29 21:11  tmp6yuj5k0m
# 1582087 -rw-------  1 luis luis    0 oct 29 20:54  tmp6zocw5ty
# 1582180 -rw-------  1 luis luis    0 oct 29 21:01  tmp700rov9r
# 1583924 -rw-------  1 luis luis    0 oct 29 21:44  tmp70wmsbbm
# 1582230 -rw-------  1 luis luis    0 oct 29 21:04  tmp71z3u29r
# 1583934 -rw-------  1 luis luis    0 oct 29 21:45  tmp73090lgz
# 1582123 -rw-------  1 luis luis    0 oct 29 20:57  tmp750iare6
# 1582135 -rw-------  1 luis luis    0 oct 29 20:57  tmp772x0hbo
# 1575085 -rw-------  1 luis luis    0 oct 29 20:46  tmp785t0rst
# 1583573 -rw-------  1 luis luis    0 oct 29 21:22  tmp788iu4gz
# 1583812 -rw-------  1 luis luis    0 oct 29 21:37  tmp79sbf6e_
# 1584027 -rw-------  1 luis luis    0 oct 29 21:51  tmp7abxl8sm
# 1583701 -rw-------  1 luis luis    0 oct 29 21:31  tmp7c42g2jn
# 1583896 -rw-------  1 luis luis    0 oct 29 21:42  tmp7cbz4zra
# 1582119 -rw-------  1 luis luis    0 oct 29 20:56  tmp7dj3tjiu
# 1583888 -rw-------  1 luis luis    0 oct 29 21:42  tmp7djd17bn
# 1582228 -rw-------  1 luis luis    0 oct 29 21:04  tmp7d_nuzj4
# 1583875 -rw-------  1 luis luis    0 oct 29 21:41  tmp7ew9srzq
# 1583608 -rw-------  1 luis luis    0 oct 29 21:25  tmp7iazdz3_
# 1583628 -rw-------  1 luis luis    0 oct 29 21:26  tmp7kc649td
# 1575063 -rw-------  1 luis luis    0 oct 29 20:45  tmp7_kd1qe4
# 1583712 -rw-------  1 luis luis    0 oct 29 21:31  tmp7lvg2a7s
# 1583516 -rw-------  1 luis luis    0 oct 29 21:18  tmp7n0oucs_
# 1583444 -rw-------  1 luis luis    0 oct 29 21:14  tmp7nprj9gf
# 1582121 -rw-------  1 luis luis    0 oct 29 20:57  tmp7phnwitm
# 1584037 -rw-------  1 luis luis    0 oct 29 21:51  tmp_7q5id8w
# 1582143 -rw-------  1 luis luis    0 oct 29 20:58  tmp7qesime1
# 1583404 -rw-------  1 luis luis    0 oct 29 21:11  tmp7qjzlsl7
# 1583622 -rw-------  1 luis luis    0 oct 29 21:25  tmp7sbdbkys
# 1583739 -rw-------  1 luis luis    0 oct 29 21:33  tmp7slhp8h4
# 1583521 -rw-------  1 luis luis    0 oct 29 21:19  tmp7t1hw0h7
# 1583510 -rw-------  1 luis luis    0 oct 29 21:18  tmp7urjmtvv
# 1575079 -rw-------  1 luis luis    0 oct 29 20:46  tmp7v0l3668
# 1583720 -rw-------  1 luis luis    0 oct 29 21:32  tmp_7xktoz_
# 1575149 -rw-------  1 luis luis    0 oct 29 20:47  tmp7zvvggdv
# 1582240 -rw-------  1 luis luis    0 oct 29 21:05  tmp80sk_wzq
# 1584013 -rw-------  1 luis luis    0 oct 29 21:50  tmp81k6hxtu
# 1575073 -rw-------  1 luis luis    0 oct 29 20:45  tmp81sgrkir
# 1584025 -rw-------  1 luis luis    0 oct 29 21:50  tmp83e5jd37
# 1580792 -rw-------  1 luis luis    0 oct 29 20:50  tmp84c61bqv
# 1583913 -rw-------  1 luis luis    0 oct 29 21:43  tmp88sm52uy
# 1583816 -rw-------  1 luis luis    0 oct 29 21:37  tmp8bcuznl6
# 1583784 -rw-------  1 luis luis    0 oct 29 21:35  tmp8cbf_p39
# 1583691 -rw-------  1 luis luis    0 oct 29 21:30  tmp8cmoai8i
# 1583981 -rw-------  1 luis luis    0 oct 29 21:48  tmp8eh3eq68
# 1583520 -rw-------  1 luis luis    0 oct 29 21:19  tmp8ksvv8wh
# 1583664 -rw-------  1 luis luis    0 oct 29 21:28  tmp8laditbp
# 1582096 -rw-------  1 luis luis    0 oct 29 20:55  tmp8ldlzg64
# 1583910 -rw-------  1 luis luis    0 oct 29 21:43  tmp8ls6y9v7
# 1580814 -rw-------  1 luis luis    0 oct 29 20:51  tmp8lz72wa7
# 1578118 -rw-------  1 luis luis    0 oct 29 20:49  tmp8mad48rx
# 1584003 -rw-------  1 luis luis    0 oct 29 21:49  tmp8pg_8bgu
# 1583470 -rw-------  1 luis luis    0 oct 29 21:15  tmp8qtp6n_v
# 1582169 -rw-------  1 luis luis    0 oct 29 21:00  tmp8r4g8oua
# 1582414 -rw-------  1 luis luis    0 oct 29 21:06  tmp8sf0dr9b
# 1582126 -rw-------  1 luis luis    0 oct 29 20:57  tmp8sn72xqm
# 1583810 -rw-------  1 luis luis    0 oct 29 21:36  tmp8_srpq52
# 1582449 -rw-------  1 luis luis    0 oct 29 21:09  tmp8vmyli9_
# 1583736 -rw-------  1 luis luis    0 oct 29 21:33  tmp8_xc_7pj
# 1583952 -rw-------  1 luis luis    0 oct 29 21:46  tmp8xrkp1ze
# 1580804 -rw-------  1 luis luis    0 oct 29 20:51  tmp8yiaceku
# 1583389 -rw-------  1 luis luis    0 oct 29 21:10  tmp8ym01kae
# 1580946 -rw-------  1 luis luis    0 oct 29 20:53  tmp8yvbh7pe
# 1583785 -rw-------  1 luis luis    0 oct 29 21:35  tmp8yvswa37
# 1583988 -rw-------  1 luis luis    0 oct 29 21:48  tmp8zr1wzjh
# 1575106 -rw-------  1 luis luis    0 oct 29 20:46  tmp92a8ku1g
# 1583462 -rw-------  1 luis luis    0 oct 29 21:15  tmp93i8ujgb
# 1583776 -rw-------  1 luis luis    0 oct 29 21:34  tmp980iupa3
# 1583402 -rw-------  1 luis luis    0 oct 29 21:11  tmp991o0t21
# 1583588 -rw-------  1 luis luis    0 oct 29 21:23  tmp99xq4cxt
# 1583903 -rw-------  1 luis luis    0 oct 29 21:43  tmp9bm_zwh0
# 1575157 -rw-------  1 luis luis    0 oct 29 20:48  tmp9d7gt9w2
# 1583551 -rw-------  1 luis luis    0 oct 29 21:21  tmp9f9lfm0d
# 1583508 -rw-------  1 luis luis    0 oct 29 21:18  tmp9fazmr5e
# 1583927 -rw-------  1 luis luis    0 oct 29 21:44  tmp9gii4tdz
# 1582144 -rw-------  1 luis luis    0 oct 29 20:58  tmp9j6rei1p
# 1583781 -rw-------  1 luis luis    0 oct 29 21:34  tmp9lkoglvb
# 1583949 -rw-------  1 luis luis    0 oct 29 21:46  tmp9nwpdor6
# 1582176 -rw-------  1 luis luis    0 oct 29 21:00  tmp9qp9gvbl
# 1583399 -rw-------  1 luis luis    0 oct 29 21:11  tmp9qv8luih
# 1580796 -rw-------  1 luis luis    0 oct 29 20:50  tmp9qvvpcj7
# 1583714 -rw-------  1 luis luis    0 oct 29 21:31  tmp9qwrj_z_
# 1583846 -rw-------  1 luis luis    0 oct 29 21:39  tmp9rej5d11
# 1575161 -rw-------  1 luis luis    0 oct 29 20:48  tmp9rltk8d6
# 1583651 -rw-------  1 luis luis    0 oct 29 21:27  tmp9rprc_f9
# 1582082 -rw-------  1 luis luis    0 oct 29 20:54  tmp9ru895vw
# 1583734 -rw-------  1 luis luis    0 oct 29 21:33  tmp9so723e6
# 1575072 -rw-------  1 luis luis    0 oct 29 20:45  tmp9uc07so3
# 1580820 -rw-------  1 luis luis    0 oct 29 20:52  tmp9x_2kble
# 1582196 -rw-------  1 luis luis    0 oct 29 21:02  tmp_a0p99s3
# 1583405 -rw-------  1 luis luis    0 oct 29 21:11  tmpa1jru28h
# 1583851 -rw-------  1 luis luis    0 oct 29 21:39  tmpa39uwo9c
# 1583907 -rw-------  1 luis luis    0 oct 29 21:43  tmpa3b754kn
# 1583504 -rw-------  1 luis luis    0 oct 29 21:18  tmpa886x2qt
# 1583822 -rw-------  1 luis luis    0 oct 29 21:37  tmpa8nhmrr5
# 1584029 -rw-------  1 luis luis    0 oct 29 21:51  tmpaahwc7od
# 1582163 -rw-------  1 luis luis    0 oct 29 20:59  tmpackrj4g4
# 1583655 -rw-------  1 luis luis    0 oct 29 21:28  tmpadv4ao_w
# 1583953 -rw-------  1 luis luis    0 oct 29 21:46  tmpaei3znt5
# 1583740 -rw-------  1 luis luis    0 oct 29 21:33  tmpafd3ull8
# 1582440 -rw-------  1 luis luis    0 oct 29 21:08  tmpaferka8p
# 1583786 -rw-------  1 luis luis    0 oct 29 21:35  tmpag3inmr9
# 1575111 -rw-------  1 luis luis    0 oct 29 20:46  tmpalu6w4qz
# 1583890 -rw-------  1 luis luis    0 oct 29 21:42  tmpam7pdzdu
# 1582212 -rw-------  1 luis luis    0 oct 29 21:03  tmpamw02opc
# 1582214 -rw-------  1 luis luis    0 oct 29 21:03  tmpan2ys3y4
# 1575089 -rw-------  1 luis luis    0 oct 29 20:46  tmpan9fmcsc
# 1583660 -rw-------  1 luis luis    0 oct 29 21:28  tmpank4hyvl
# 1583638 -rw-------  1 luis luis    0 oct 29 21:26  tmpapbgjnba
# 1583767 -rw-------  1 luis luis    0 oct 29 21:34  tmpaq3hlfbz
# 1582198 -rw-------  1 luis luis    0 oct 29 21:02  tmpaqd76fc7
# 1583640 -rw-------  1 luis luis    0 oct 29 21:27  tmpav1j_052
# 1583523 -rw-------  1 luis luis    0 oct 29 21:19  tmpavq_wz68
# 1575135 -rw-------  1 luis luis    0 oct 29 20:47  tmp_awdkuh3
# 1583390 -rw-------  1 luis luis    0 oct 29 21:10  tmpaypdfpnf
# 1575156 -rw-------  1 luis luis    0 oct 29 20:47  tmpayrk4w59
# 1582446 -rw-------  1 luis luis    0 oct 29 21:09  tmpaz1nk6f9
# 1584009 -rw-------  1 luis luis    0 oct 29 21:50  tmpa_zuekcp
# 1584001 -rw-------  1 luis luis    0 oct 29 21:49  tmpb11g68ji
# 1583818 -rw-------  1 luis luis    0 oct 29 21:37  tmpb1l0pd4j
# 1582160 -rw-------  1 luis luis    0 oct 29 20:59  tmpb21at6y4
# 1583663 -rw-------  1 luis luis    0 oct 29 21:28  tmpb2qbq7ui
# 1583905 -rw-------  1 luis luis    0 oct 29 21:43  tmpb3hrtrqe
# 1582145 -rw-------  1 luis luis    0 oct 29 20:58  tmpb5drhef7
# 1583690 -rw-------  1 luis luis    0 oct 29 21:30  tmpb5ey6567
# 1584026 -rw-------  1 luis luis    0 oct 29 21:50  tmpb6xa0p7s
# 1583685 -rw-------  1 luis luis    0 oct 29 21:30  tmpb7v6dlw6
# 1583454 -rw-------  1 luis luis    0 oct 29 21:14  tmpb836isj2
# 1583725 -rw-------  1 luis luis    0 oct 29 21:32  tmpb848jzjy
# 1582234 -rw-------  1 luis luis    0 oct 29 21:04  tmpb8by_w9g
# 1583519 -rw-------  1 luis luis    0 oct 29 21:19  tmpb91e2y25
# 1575163 -rw-------  1 luis luis    0 oct 29 20:48  tmpb92mftyl
# 1583733 -rw-------  1 luis luis    0 oct 29 21:33  tmpbaa09wne
# 1583668 -rw-------  1 luis luis    0 oct 29 21:29  tmpbcj28n51
# 1582422 -rw-------  1 luis luis    0 oct 29 21:07  tmpbg8ibro_
# 1583590 -rw-------  1 luis luis    0 oct 29 21:23  tmpbhaqbkib
# 1583835 -rw-------  1 luis luis    0 oct 29 21:38  tmpbjs561vn
# 1582191 -rw-------  1 luis luis    0 oct 29 21:01  tmpbl3tf29p
# 1583489 -rw-------  1 luis luis    0 oct 29 21:17  tmpbl659c85
# 1583696 -rw-------  1 luis luis    0 oct 29 21:30  tmpblaovd4u
# 1582223 -rw-------  1 luis luis    0 oct 29 21:03  tmpbne83svk
# 1583429 -rw-------  1 luis luis    0 oct 29 21:13  tmpboe6o0dt
# 1582098 -rw-------  1 luis luis    0 oct 29 20:55  tmpbpgw_cmp
# 1583916 -rw-------  1 luis luis    0 oct 29 21:43  tmpbq75hir8
# 1582103 -rw-------  1 luis luis    0 oct 29 20:55  tmpbtumfbrp
# 1580825 -rw-------  1 luis luis    0 oct 29 20:52  tmpbtuuk8le
# 1583665 -rw-------  1 luis luis    0 oct 29 21:28  tmpbud4d11a
# 1583401 -rw-------  1 luis luis    0 oct 29 21:11  tmpbue30gni
# 1583918 -rw-------  1 luis luis    0 oct 29 21:43  tmpbxuhla1r
# 1583996 -rw-------  1 luis luis    0 oct 29 21:49  tmpby_dqn8r
# 1582451 -rw-------  1 luis luis    0 oct 29 21:09  tmpbzxdmbr5
# 1583817 -rw-------  1 luis luis    0 oct 29 21:37  tmpc11sxd4i
# 1580808 -rw-------  1 luis luis    0 oct 29 20:51  tmpc3gctlc0
# 1582443 -rw-------  1 luis luis    0 oct 29 21:08  tmpc886yyxf
# 1583787 -rw-------  1 luis luis    0 oct 29 21:35  tmpc9g2qu3_
# 1583965 -rw-------  1 luis luis    0 oct 29 21:47  tmpcc2dy72t
# 1583541 -rw-------  1 luis luis    0 oct 29 21:20  tmpccqz2g7m
# 1583662 -rw-------  1 luis luis    0 oct 29 21:28  tmpcgv5c18d
# 1583437 -rw-------  1 luis luis    0 oct 29 21:13  tmpcjvlnc_q
# 1583921 -rw-------  1 luis luis    0 oct 29 21:44  tmpclfvz77x
# 1582444 -rw-------  1 luis luis    0 oct 29 21:08  tmpcll7tb1l
# 1582438 -rw-------  1 luis luis    0 oct 29 21:08  tmpcnpet1ay
# 1583790 -rw-------  1 luis luis    0 oct 29 21:35  tmpcqfaww_u
# 1582418 -rw-------  1 luis luis    0 oct 29 21:07  tmpcqwn6m5z
# 1583617 -rw-------  1 luis luis    0 oct 29 21:25  tmpcr7jfluy
# 1583612 -rw-------  1 luis luis    0 oct 29 21:25  tmpcrcq3lzr
# 1582142 -rw-------  1 luis luis    0 oct 29 20:58  tmpcse5p72u
# 1584004 -rw-------  1 luis luis    0 oct 29 21:49  tmpct5o5un4
# 1583695 -rw-------  1 luis luis    0 oct 29 21:30  tmpctz0jfc3
# 1583962 -rw-------  1 luis luis    0 oct 29 21:46  tmpcuvoa59c
# 1575160 -rw-------  1 luis luis    0 oct 29 20:48  tmpcux_3hsg
# 1582158 -rw-------  1 luis luis    0 oct 29 20:59  tmpcyd22s_p
# 1583858 -rw-------  1 luis luis    0 oct 29 21:39  tmpd1apt7pa
# 1583457 -rw-------  1 luis luis    0 oct 29 21:14  tmpd2ie5i9k
# 1583482 -rw-------  1 luis luis    0 oct 29 21:16  tmpd3jizz7q
# 1583459 -rw-------  1 luis luis    0 oct 29 21:15  tmpd_48j6yx
# 1583964 -rw-------  1 luis luis    0 oct 29 21:47  tmpd4zfr_zm
# 1583604 -rw-------  1 luis luis    0 oct 29 21:24  tmpd55u32ib
# 1575097 -rw-------  1 luis luis    0 oct 29 20:46  tmpd6sh39kt
# 1582170 -rw-------  1 luis luis    0 oct 29 21:00  tmpd7305pm_
# 1580953 -rw-------  1 luis luis    0 oct 29 20:53  tmpd9r6zm6q
# 1583768 -rw-------  1 luis luis    0 oct 29 21:34  tmpda5aw2z_
# 1583545 -rw-------  1 luis luis    0 oct 29 21:20  tmp_dapfp3a
# 1583600 -rw-------  1 luis luis    0 oct 29 21:24  tmpdbf6x9_c
# 1583766 -rw-------  1 luis luis    0 oct 29 21:33  tmpdcjdijyt
# 1582186 -rw-------  1 luis luis    0 oct 29 21:01  tmpdcrhfzv6
# 1583702 -rw-------  1 luis luis    0 oct 29 21:31  tmpddfwrqb2
# 1583800 -rw-------  1 luis luis    0 oct 29 21:36  tmpde_0_35w
# 1583867 -rw-------  1 luis luis    0 oct 29 21:40  tmpdfirq_uk
# 1580772 -rw-------  1 luis luis    0 oct 29 20:49  tmpdlikpmja
# 1583563 -rw-------  1 luis luis    0 oct 29 21:22  tmpdlpvld7p
# 1582088 -rw-------  1 luis luis    0 oct 29 20:54  tmpdmcgsmdi
# 1582155 -rw-------  1 luis luis    0 oct 29 20:59  tmpd_mfs62i
# 1583870 -rw-------  1 luis luis    0 oct 29 21:40  tmpdno6niao
# 1583891 -rw-------  1 luis luis    0 oct 29 21:42  tmpdnzfqh6n
# 1579806 -rw-------  1 luis luis    0 oct 29 20:49  tmpdr7ao2qq
# 1583893 -rw-------  1 luis luis    0 oct 29 21:42  tmpduulssf3
# 1583397 -rw-------  1 luis luis    0 oct 29 21:10  tmpe_1fds7h
# 1580769 -rw-------  1 luis luis    0 oct 29 20:49  tmpe2dntqg6
# 1582185 -rw-------  1 luis luis    0 oct 29 21:01  tmpe3ytszaq
# 1583533 -rw-------  1 luis luis    0 oct 29 21:19  tmpe4ihtx5n
# 1583534 -rw-------  1 luis luis    0 oct 29 21:19  tmpe53wfbg5
# 1583661 -rw-------  1 luis luis    0 oct 29 21:28  tmpe5hb3vlh
# 1582107 -rw-------  1 luis luis    0 oct 29 20:55  tmpe7ttwth1
# 1583957 -rw-------  1 luis luis    0 oct 29 21:46  tmpeax3ehxi
# 1583648 -rw-------  1 luis luis    0 oct 29 21:27  tmpebpz68me
# 1580795 -rw-------  1 luis luis    0 oct 29 20:50  tmped1q3y71
# 1583478 -rw-------  1 luis luis    0 oct 29 21:16  tmpedcflxc4
# 1582407 -rw-------  1 luis luis    0 oct 29 21:06  tmpef853aj2
# 1584010 -rw-------  1 luis luis    0 oct 29 21:50  tmpeh190mqf
# 1582239 -rw-------  1 luis luis    0 oct 29 21:04  tmpelpvq15r
# 1580941 -rw-------  1 luis luis    0 oct 29 20:53  tmpemgaixyb
# 1583806 -rw-------  1 luis luis    0 oct 29 21:36  tmpernbkxqn
# 1583393 -rw-------  1 luis luis    0 oct 29 21:10  tmpers9751n
# 1583593 -rw-------  1 luis luis    0 oct 29 21:23  tmpersel7ej
# 1582171 -rw-------  1 luis luis    0 oct 29 21:00  tmpesczbvh0
# 1583480 -rw-------  1 luis luis    0 oct 29 21:16  tmpetq76ojc
# 1583897 -rw-------  1 luis luis    0 oct 29 21:42  tmpevqdz18t
# 1582101 -rw-------  1 luis luis    0 oct 29 20:55  tmpew7pwk76
# 1583460 -rw-------  1 luis luis    0 oct 29 21:15  tmpeyedei3p
# 1583845 -rw-------  1 luis luis    0 oct 29 21:39  tmp_eyvudsd
# 1580957 -rw-------  1 luis luis    0 oct 29 20:53  tmpf1_5heka
# 1583895 -rw-------  1 luis luis    0 oct 29 21:42  tmpf26s_qpk
# 1583495 -rw-------  1 luis luis    0 oct 29 21:17  tmpf3sxzopr
# 1583574 -rw-------  1 luis luis    0 oct 29 21:22  tmpf5bu4ej6
# 1583826 -rw-------  1 luis luis    0 oct 29 21:37  tmpf93u8oul
# 1583492 -rw-------  1 luis luis    0 oct 29 21:17  tmpf96gaeuz
# 1580823 -rw-------  1 luis luis    0 oct 29 20:52  tmpfatt1z1a
# 1583428 -rw-------  1 luis luis    0 oct 29 21:13  tmpfay3gwfy
# 1580785 -rw-------  1 luis luis    0 oct 29 20:50  tmpfboel8yv
# 1583670 -rw-------  1 luis luis    0 oct 29 21:29  tmpfbsqq15r
# 1583980 -rw-------  1 luis luis    0 oct 29 21:48  tmpfcj6dbgk
# 1582430 -rw-------  1 luis luis    0 oct 29 21:07  tmpfdb1azjs
# 1583874 -rw-------  1 luis luis    0 oct 29 21:41  tmpfdrzr0rv
# 1583886 -rw-------  1 luis luis    0 oct 29 21:41  tmpfe6np22w
# 1583646 -rw-------  1 luis luis    0 oct 29 21:27  tmpfefhi9fe
# 1583855 -rw-------  1 luis luis    0 oct 29 21:39  tmpff2d56kv
# 1583966 -rw-------  1 luis luis    0 oct 29 21:47  tmpff6l71zs
# 1583983 -rw-------  1 luis luis    0 oct 29 21:48  tmpffaipny3
# 1583620 -rw-------  1 luis luis    0 oct 29 21:25  tmpfgoeqmxo
# 1583961 -rw-------  1 luis luis    0 oct 29 21:46  tmpfgt_kixg
# 1583493 -rw-------  1 luis luis    0 oct 29 21:17  tmpfhe9pgd6
# 1583801 -rw-------  1 luis luis    0 oct 29 21:36  tmpfj9dahi2
# 1583602 -rw-------  1 luis luis    0 oct 29 21:24  tmpflcj_vyr
# 1583540 -rw-------  1 luis luis    0 oct 29 21:20  tmpfo_wfp36
# 1583803 -rw-------  1 luis luis    0 oct 29 21:36  tmpfpf8s5ca
# 1582238 -rw-------  1 luis luis    0 oct 29 21:04  tmpfqj65ly0
# 1582099 -rw-------  1 luis luis    0 oct 29 20:55  tmpfrqfho8y
# 1584040 -rw-------  1 luis luis    0 oct 29 21:51  tmpfrv8eebx
# 1582112 -rw-------  1 luis luis    0 oct 29 20:56  tmpfsgco3iu
# 1583987 -rw-------  1 luis luis    0 oct 29 21:48  tmpfx6bl0dx
# 1583943 -rw-------  1 luis luis    0 oct 29 21:45  tmpfy37qi4a
# 1583479 -rw-------  1 luis luis    0 oct 29 21:16  tmpfy5rz5er
# 1583411 -rw-------  1 luis luis    0 oct 29 21:11  tmpfyo7y9q8
# 1583707 -rw-------  1 luis luis    0 oct 29 21:31  tmpfyyb7uqf
# 1582445 -rw-------  1 luis luis    0 oct 29 21:08  tmpfz_hqtvj
# 1582226 -rw-------  1 luis luis    0 oct 29 21:03  tmpg486qf31
# 1583970 -rw-------  1 luis luis    0 oct 29 21:47  tmpg48v_h7f
# 1583920 -rw-------  1 luis luis    0 oct 29 21:44  tmpg5uxe7nt
# 1583496 -rw-------  1 luis luis    0 oct 29 21:17  tmpg6a1kvs8
# 1583634 -rw-------  1 luis luis    0 oct 29 21:26  tmpg6fq4wz9
# 1583948 -rw-------  1 luis luis    0 oct 29 21:46  tmpg_6iu19k
# 1582442 -rw-------  1 luis luis    0 oct 29 21:08  tmpg6s0ymr8
# 1582382 -rw-------  1 luis luis    0 oct 29 21:06  tmpg7fntny5
# 1582102 -rw-------  1 luis luis    0 oct 29 20:55  tmpg8wkd02o
# 1575158 -rw-------  1 luis luis    0 oct 29 20:48  tmpgapcl9x3
# 1583632 -rw-------  1 luis luis    0 oct 29 21:26  tmpgbxlkumh
# 1583500 -rw-------  1 luis luis    0 oct 29 21:17  tmpgdeyj1_m
# 1583652 -rw-------  1 luis luis    0 oct 29 21:27  tmpgh3z30jq
# 1583601 -rw-------  1 luis luis    0 oct 29 21:24  tmpghoirb4h
# 1584041 -rw-------  1 luis luis    0 oct 29 21:51  tmpghwir7kt
# 1583678 -rw-------  1 luis luis    0 oct 29 21:29  tmpgjwzvefv
# 1580961 -rw-------  1 luis luis    0 oct 29 20:54  tmpgk80i8y6
# 1583730 -rw-------  1 luis luis    0 oct 29 21:33  tmpglj8tpui
# 1584039 -rw-------  1 luis luis    0 oct 29 21:51  tmpglm0a3i_
# 1583560 -rw-------  1 luis luis    0 oct 29 21:21  tmpglojrwjr
# 1583782 -rw-------  1 luis luis    0 oct 29 21:34  tmpgm__dyfb
# 1582217 -rw-------  1 luis luis    0 oct 29 21:03  tmpgme0q9y9
# 1582125 -rw-------  1 luis luis    0 oct 29 20:57  tmpgn4zp5e_
# 1583708 -rw-------  1 luis luis    0 oct 29 21:31  tmpgol8hddn
# 1583535 -rw-------  1 luis luis    0 oct 29 21:20  tmpgozu4pvo
# 1583529 -rw-------  1 luis luis    0 oct 29 21:19  tmpgqhzgw55
# 1583876 -rw-------  1 luis luis    0 oct 29 21:41  tmpgrqhjddw
# 1583738 -rw-------  1 luis luis    0 oct 29 21:33  tmpgxp6fwxt
# 1579824 -rw-------  1 luis luis    0 oct 29 20:49  tmpgyc3eov5
# 1583860 -rw-------  1 luis luis    0 oct 29 21:40  tmpgze7_t9e
# 1583711 -rw-------  1 luis luis    0 oct 29 21:31  tmpgzhzd1iz
# 1583721 -rw-------  1 luis luis    0 oct 29 21:32  tmph04kjwl_
# 1583487 -rw-------  1 luis luis    0 oct 29 21:17  tmph2d1fzvg
# 1583933 -rw-------  1 luis luis    0 oct 29 21:45  tmph6wicjrw
# 1583434 -rw-------  1 luis luis    0 oct 29 21:13  tmph8nntfgt
# 1582249 -rw-------  1 luis luis    0 oct 29 21:05  tmph910fppt
# 1583932 -rw-------  1 luis luis    0 oct 29 21:45  tmph9c9qvda
# 1583653 -rw-------  1 luis luis    0 oct 29 21:27  tmphcdoc6tq
# 1583379 -rw-------  1 luis luis    0 oct 29 21:09  tmphfer9m0i
# 1582455 -rw-------  1 luis luis    0 oct 29 21:09  tmphg9n2pct
# 1583490 -rw-------  1 luis luis    0 oct 29 21:17  tmp_hii_9wz
# 1575119 -rw-------  1 luis luis    0 oct 29 20:47  tmphiyo3k06
# 1583866 -rw-------  1 luis luis    0 oct 29 21:40  tmphnmyra8z
# 1583877 -rw-------  1 luis luis    0 oct 29 21:41  tmphqk6lb5_
# 1583515 -rw-------  1 luis luis    0 oct 29 21:18  tmphsflnh6d
# 1584016 -rw-------  1 luis luis    0 oct 29 21:50  tmphsl0o6sc
# 1583391 -rw-------  1 luis luis    0 oct 29 21:10  tmphucuykr3
# 1583797 -rw-------  1 luis luis    0 oct 29 21:35  tmphv8jybgz
# 1583700 -rw-------  1 luis luis    0 oct 29 21:31  tmphvdcs7m6
# 1583432 -rw-------  1 luis luis    0 oct 29 21:13  tmphz57bupw
# 1583587 -rw-------  1 luis luis    0 oct 29 21:23  tmpi168ijwb
# 1582093 -rw-------  1 luis luis    0 oct 29 20:55  tmpi1sv6f_x
# 1583919 -rw-------  1 luis luis    0 oct 29 21:44  tmpi1zlfs_g
# 1583413 -rw-------  1 luis luis    0 oct 29 21:11  tmpi35vl3ag
# 1583623 -rw-------  1 luis luis    0 oct 29 21:26  tmpi64ycut5
# 1583561 -rw-------  1 luis luis    0 oct 29 21:21  tmpi9jij652
# 1583424 -rw-------  1 luis luis    0 oct 29 21:12  tmpiamv7ppz
# 1583783 -rw-------  1 luis luis    0 oct 29 21:35  tmpierat930
# 1580782 -rw-------  1 luis luis    0 oct 29 20:50  tmpif9hb84y
# 1583472 -rw-------  1 luis luis    0 oct 29 21:15  tmpiivgq5d3
# 1582193 -rw-------  1 luis luis    0 oct 29 21:01  tmpiixbwjsv
# 1583780 -rw-------  1 luis luis    0 oct 29 21:34  tmpij_1vtwv
# 1582120 -rw-------  1 luis luis    0 oct 29 20:57  tmpik9shqga
# 1583452 -rw-------  1 luis luis    0 oct 29 21:14  tmpikeybouk
# 1582227 -rw-------  1 luis luis    0 oct 29 21:03  tmpikrl3p8v
# 1583568 -rw-------  1 luis luis    0 oct 29 21:22  tmpikxz1xnf
# 1583831 -rw-------  1 luis luis    0 oct 29 21:38  tmpin7lk7jm
# 1583699 -rw-------  1 luis luis    0 oct 29 21:31  tmpinyg2h23
# 1583446 -rw-------  1 luis luis    0 oct 29 21:14  tmpirxw4y4j
# 1582255 -rw-------  1 luis luis    0 oct 29 21:05  tmpisplanpk
# 1583955 -rw-------  1 luis luis    0 oct 29 21:46  tmpiunvpe86
# 1583658 -rw-------  1 luis luis    0 oct 29 21:28  tmpj03nnid4
# 1583802 -rw-------  1 luis luis    0 oct 29 21:36  tmpj06lkdi5
# 1583940 -rw-------  1 luis luis    0 oct 29 21:45  tmpj0hsh_ki
# 1583674 -rw-------  1 luis luis    0 oct 29 21:29  tmpj13654sm
# 1582221 -rw-------  1 luis luis    0 oct 29 21:03  tmpj3kqr8m5
# 1582092 -rw-------  1 luis luis    0 oct 29 20:55  tmpj65fbpea
# 1582078 -rw-------  1 luis luis    0 oct 29 20:54  tmpj9j444gb
# 1583823 -rw-------  1 luis luis    0 oct 29 21:37  tmpjclt3njd
# 1583637 -rw-------  1 luis luis    0 oct 29 21:26  tmpjfebb8kw
# 1583384 -rw-------  1 luis luis    0 oct 29 21:10  tmpjgvt0y3y
# 1582097 -rw-------  1 luis luis    0 oct 29 20:55  tmpjjiv_i2q
# 1582168 -rw-------  1 luis luis    0 oct 29 21:00  tmpjkg6c9v7
# 1582415 -rw-------  1 luis luis    0 oct 29 21:06  tmpjphhc0qf
# 1583885 -rw-------  1 luis luis    0 oct 29 21:41  tmpjs5yqxa7
# 1582182 -rw-------  1 luis luis    0 oct 29 21:01  tmpjsnxh1i7
# 1582450 -rw-------  1 luis luis    0 oct 29 21:09  tmpjspksbf3
# 1575074 -rw-------  1 luis luis    0 oct 29 20:46  tmpjvkn9mgq
# 1582156 -rw-------  1 luis luis    0 oct 29 20:59  tmpjxdmgpe9
# 1583878 -rw-------  1 luis luis    0 oct 29 21:41  tmpjyrd3vli
# 1583969 -rw-------  1 luis luis    0 oct 29 21:47  tmpjz5s0jbj
# 1583595 -rw-------  1 luis luis    0 oct 29 21:24  tmpk3r6ot6z
# 1583705 -rw-------  1 luis luis    0 oct 29 21:31  tmpk3vx3zbu
# 1582189 -rw-------  1 luis luis    0 oct 29 21:01  tmpk81zby9z
# 1582431 -rw-------  1 luis luis    0 oct 29 21:07  tmpk8s2rq_i
# 1582243 -rw-------  1 luis luis    0 oct 29 21:05  tmpk9yfbwkm
# 1583378 -rw-------  1 luis luis    0 oct 29 21:09  tmpkb889x7j
# 1582207 -rw-------  1 luis luis    0 oct 29 21:02  tmpkbm_fg1v
# 1575155 -rw-------  1 luis luis    0 oct 29 20:47  tmpkdiczrtj
# 1583497 -rw-------  1 luis luis    0 oct 29 21:17  tmpkerkjegd
# 1583400 -rw-------  1 luis luis    0 oct 29 21:11  tmpkfuxf9nk
# 1583591 -rw-------  1 luis luis    0 oct 29 21:23  tmpkhkpz3mj
# 1582187 -rw-------  1 luis luis    0 oct 29 21:01  tmpkhmua4dv
# 1575096 -rw-------  1 luis luis    0 oct 29 20:46  tmpki5r5kds
# 1580937 -rw-------  1 luis luis    0 oct 29 20:52  tmpkikz4rey
# 1575124 -rw-------  1 luis luis    0 oct 29 20:47  tmpkj5a7hcp
# 1580811 -rw-------  1 luis luis    0 oct 29 20:51  tmpkkhfkotw
# 1583582 -rw-------  1 luis luis    0 oct 29 21:23  tmpklc4zj48
# 1583672 -rw-------  1 luis luis    0 oct 29 21:29  tmpkmk4hlq_
# 1583772 -rw-------  1 luis luis    0 oct 29 21:34  tmpkml94rvh
# 1575166 -rw-------  1 luis luis    0 oct 29 20:48  tmpkmqttgxg
# 1583894 -rw-------  1 luis luis    0 oct 29 21:42  tmpknmz9_88
# 1575055 -rw-r--r--  1 luis luis 7.7M oct 29 17:23  tmp-knu.xpi
# 1582147 -rw-------  1 luis luis    0 oct 29 20:58  tmpkokjevnj
# 1583709 -rw-------  1 luis luis    0 oct 29 21:31  tmpkpsmv_0e
# 1583633 -rw-------  1 luis luis    0 oct 29 21:26  tmpkq2bv7i9
# 1582094 -rw-------  1 luis luis    0 oct 29 20:55  tmpkqh6gaor
# 1583703 -rw-------  1 luis luis    0 oct 29 21:31  tmpkqu007e6
# 1580958 -rw-------  1 luis luis    0 oct 29 20:53  tmpksab5scw
# 1583862 -rw-------  1 luis luis    0 oct 29 21:40  tmpksqs8s1c
# 1583606 -rw-------  1 luis luis    0 oct 29 21:24  tmpkv8wy57v
# 1583439 -rw-------  1 luis luis    0 oct 29 21:13  tmpkva3jj2v
# 1583639 -rw-------  1 luis luis    0 oct 29 21:27  tmpkvshrhsd
# 1582441 -rw-------  1 luis luis    0 oct 29 21:08  tmpkxnhhw7z
# 1582141 -rw-------  1 luis luis    0 oct 29 20:58  tmpkxsdq6yc
# 1583626 -rw-------  1 luis luis    0 oct 29 21:26  tmpkz4023mh
# 1583649 -rw-------  1 luis luis    0 oct 29 21:27  tmpkz6snxy4
# 1583979 -rw-------  1 luis luis    0 oct 29 21:48  tmpkzu3kmpr
# 1583914 -rw-------  1 luis luis    0 oct 29 21:43  tmpl08mnsz6
# 1580819 -rw-------  1 luis luis    0 oct 29 20:52  tmpl0ruu0u5
# 1583950 -rw-------  1 luis luis    0 oct 29 21:46  tmpl1f6gmxd
# 1583881 -rw-------  1 luis luis    0 oct 29 21:41  tmpl1oosoy2
# 1582244 -rw-------  1 luis luis    0 oct 29 21:05  tmpl6py7brs
# 1583388 -rw-------  1 luis luis    0 oct 29 21:10  tmpl72bhvou
# 1583503 -rw-------  1 luis luis    0 oct 29 21:18  tmpl7u1ikc2
# 1583856 -rw-------  1 luis luis    0 oct 29 21:39  tmpl9pt3yo_
# 1583788 -rw-------  1 luis luis    0 oct 29 21:35  tmplaqu5ogz
# 1582232 -rw-------  1 luis luis    0 oct 29 21:04  tmplcsd2vdc
# 1584032 -rw-------  1 luis luis    0 oct 29 21:51  tmpld3x41i2
# 1582140 -rw-------  1 luis luis    0 oct 29 20:58  tmpled0ut5v
# 1583629 -rw-------  1 luis luis    0 oct 29 21:26  tmplee7167j
# 1583549 -rw-------  1 luis luis    0 oct 29 21:21  tmplf63j4up
# 1580781 -rw-------  1 luis luis    0 oct 29 20:50  tmplgi985o7
# 1575095 -rw-------  1 luis luis    0 oct 29 20:46  tmplh_zcibe
# 1583667 -rw-------  1 luis luis    0 oct 29 21:29  tmplive2slo
# 1583450 -rw-------  1 luis luis    0 oct 29 21:14  tmpl_jagg70
# 1583853 -rw-------  1 luis luis    0 oct 29 21:39  tmplkbmd_xd
# 1583954 -rw-------  1 luis luis    0 oct 29 21:46  tmplkiyzeiw
# 1582167 -rw-------  1 luis luis    0 oct 29 20:59  tmpllg824d7
# 1583847 -rw-------  1 luis luis    0 oct 29 21:39  tmpllpf7o6z
# 1583959 -rw-------  1 luis luis    0 oct 29 21:46  tmplme4to_x
# 1583850 -rw-------  1 luis luis    0 oct 29 21:39  tmplni1m_cq
# 1582294 -rw-------  1 luis luis    0 oct 29 21:06  tmplo0sydia
# 1583830 -rw-------  1 luis luis    0 oct 29 21:38  tmpltsvyk53
# 1582254 -rw-------  1 luis luis    0 oct 29 21:05  tmplxzub8dd
# 1580936 -rw-------  1 luis luis    0 oct 29 20:52  tmplyn6wnqp
# 1583530 -rw-------  1 luis luis    0 oct 29 21:19  tmpm0e6_k47
# 1583879 -rw-------  1 luis luis    0 oct 29 21:41  tmpm0i484zu
# 1583814 -rw-------  1 luis luis    0 oct 29 21:37  tmpm200g4d3
# 1583647 -rw-------  1 luis luis    0 oct 29 21:27  tmpm2akldpk
# 1583908 -rw-------  1 luis luis    0 oct 29 21:43  tmpm2cgo46y
# 1583494 -rw-------  1 luis luis    0 oct 29 21:17  tmpm6q47rde
# 1583477 -rw-------  1 luis luis    0 oct 29 21:16  tmpm7rz4473
# 1583698 -rw-------  1 luis luis    0 oct 29 21:30  tmpmaa56t54
# 1583547 -rw-------  1 luis luis    0 oct 29 21:21  tmpmadaavif
# 1582115 -rw-------  1 luis luis    0 oct 29 20:56  tmpmb4y8xu1
# 1583385 -rw-------  1 luis luis    0 oct 29 21:10  tmpml6xfr2t
# 1583657 -rw-------  1 luis luis    0 oct 29 21:28  tmpmngeka4b
# 1582110 -rw-------  1 luis luis    0 oct 29 20:56  tmpmq6mse36
# 1582081 -rw-------  1 luis luis    0 oct 29 20:54  tmpmsd4du3r
# 1583838 -rw-------  1 luis luis    0 oct 29 21:38  tmpmsdzas0y
# 1580952 -rw-------  1 luis luis    0 oct 29 20:53  tmpmsfk00m2
# 1583423 -rw-------  1 luis luis    0 oct 29 21:12  tmpmu8jns8x
# 1583513 -rw-------  1 luis luis    0 oct 29 21:18  tmpm_ui465j
# 1583775 -rw-------  1 luis luis    0 oct 29 21:34  tmpmvbimbdg
# 1583686 -rw-------  1 luis luis    0 oct 29 21:30  tmpmvjf_445
# 1584014 -rw-------  1 luis luis    0 oct 29 21:50  tmpmxh8x1nw
# 1578119 -rw-------  1 luis luis    0 oct 29 20:49  tmpn0ic_rlh
# 1583448 -rw-------  1 luis luis    0 oct 29 21:14  tmpn_3mbosb
# 1583414 -rw-------  1 luis luis    0 oct 29 21:11  tmpn4dzo3mf
# 1583506 -rw-------  1 luis luis    0 oct 29 21:18  tmpn4q0s8hn
# 1575060 -rw-------  1 luis luis    0 oct 29 20:45  tmpn5rv35d7
# 1583936 -rw-------  1 luis luis    0 oct 29 21:45  tmpn9jhscrk
# 1582152 -rw-------  1 luis luis    0 oct 29 20:59  tmpn9slqhfu
# 1583854 -rw-------  1 luis luis    0 oct 29 21:39  tmpn9y1lunf
# 1584042 -rw-------  1 luis luis    0 oct 29 21:51  tmpnem2e3eg
# 1583641 -rw-------  1 luis luis    0 oct 29 21:27  tmpnem_f49u
# 1583852 -rw-------  1 luis luis    0 oct 29 21:39  tmpnf5ieif1
# 1582245 -rw-------  1 luis luis    0 oct 29 21:05  tmpnfdz0ipf
# 1582124 -rw-------  1 luis luis    0 oct 29 20:57  tmpni7xzwqt
# 1575118 -rw-------  1 luis luis    0 oct 29 20:47  tmpnilklf4q
# 1583598 -rw-------  1 luis luis    0 oct 29 21:24  tmpnjkrgikr
# 1580783 -rw-------  1 luis luis    0 oct 29 20:50  tmpnl5nrak4
# 1582194 -rw-------  1 luis luis    0 oct 29 21:01  tmpnlpauitt
# 1583418 -rw-------  1 luis luis    0 oct 29 21:12  tmpnq_ksy9f
# 1582146 -rw-------  1 luis luis    0 oct 29 20:58  tmpnsmnlvt0
# 1582218 -rw-------  1 luis luis    0 oct 29 21:03  tmpnz8nbei0
# 1582161 -rw-------  1 luis luis    0 oct 29 20:59  tmpo0lt4yf5
# 1583625 -rw-------  1 luis luis    0 oct 29 21:26  tmpo1p57xwr
# 1583550 -rw-------  1 luis luis    0 oct 29 21:21  tmpo1puckd8
# 1582429 -rw-------  1 luis luis    0 oct 29 21:07  tmp_o3v5ftf
# 1583430 -rw-------  1 luis luis    0 oct 29 21:13  tmpo4_364cr
# 1583688 -rw-------  1 luis luis    0 oct 29 21:30  tmpo6yip2sc
# 1583650 -rw-------  1 luis luis    0 oct 29 21:27  tmpo7366zf9
# 1580787 -rw-------  1 luis luis    0 oct 29 20:50  tmpoc4m9me3
# 1583848 -rw-------  1 luis luis    0 oct 29 21:39  tmpoct7lxa4
# 1582203 -rw-------  1 luis luis    0 oct 29 21:02  tmpogoivcyf
# 1583978 -rw-------  1 luis luis    0 oct 29 21:47  tmpogw4bc9l
# 1583605 -rw-------  1 luis luis    0 oct 29 21:24  tmpoik0izn4
# 1580827 -rw-------  1 luis luis    0 oct 29 20:52  tmpoim_k_fy
# 1583840 -rw-------  1 luis luis    0 oct 29 21:38  tmpoiyts7t7
# 1582164 -rw-------  1 luis luis    0 oct 29 20:59  tmp_ol7441o
# 1582130 -rw-------  1 luis luis    0 oct 29 20:57  tmpolo6ilq1
# 1582242 -rw-------  1 luis luis    0 oct 29 21:05  tmpolvzrpmw
# 1582452 -rw-------  1 luis luis    0 oct 29 21:09  tmpo_meadsj
# 1582104 -rw-------  1 luis luis    0 oct 29 20:55  tmpomitfsyt
# 1583773 -rw-------  1 luis luis    0 oct 29 21:34  tmponbeladw
# 1583902 -rw-------  1 luis luis    0 oct 29 21:42  tmpoout3a2h
# 1583441 -rw-------  1 luis luis    0 oct 29 21:13  tmpopxfimoo
# 1583538 -rw-------  1 luis luis    0 oct 29 21:20  tmp_oq24erp
# 1575132 -rw-------  1 luis luis    0 oct 29 20:47  tmp_oq4dbtz
# 1583577 -rw-------  1 luis luis    0 oct 29 21:22  tmpoq53tc45
# 1583580 -rw-------  1 luis luis    0 oct 29 21:23  tmporcvsghm
# 1582122 -rw-------  1 luis luis    0 oct 29 20:57  tmpornp0voa
# 1583912 -rw-------  1 luis luis    0 oct 29 21:43  tmpos1fysyd
# 1584024 -rw-------  1 luis luis    0 oct 29 21:50  tmposbb_qev
# 1583458 -rw-------  1 luis luis    0 oct 29 21:14  tmpourxi072
# 1582406 -rw-------  1 luis luis    0 oct 29 21:06  tmp_ovbha0r
# 1584015 -rw-------  1 luis luis    0 oct 29 21:50  tmpovq313vl
# 1583997 -rw-------  1 luis luis    0 oct 29 21:49  tmpowigmnyq
# 1575098 -rw-------  1 luis luis    0 oct 29 20:46  tmpox29dobb
# 1578121 -rw-------  1 luis luis    0 oct 29 20:49  tmpp3ia50yn
# 1582447 -rw-------  1 luis luis    0 oct 29 21:09  tmpp4opv4cv
# 1583991 -rw-------  1 luis luis    0 oct 29 21:49  tmpp66gauuz
# 1583951 -rw-------  1 luis luis    0 oct 29 21:46  tmpp87auwuo
# 1583697 -rw-------  1 luis luis    0 oct 29 21:30  tmpp8dmib0r
# 1583741 -rw-------  1 luis luis    0 oct 29 21:33  tmppdbwu6ao
# 1575116 -rw-------  1 luis luis    0 oct 29 20:46  tmppf4gpunf
# 1583735 -rw-------  1 luis luis    0 oct 29 21:33  tmppf8et51j
# 1583544 -rw-------  1 luis luis    0 oct 29 21:20  tmppfvqjf3g
# 1582178 -rw-------  1 luis luis    0 oct 29 21:00  tmp_pibrwic
# 1583537 -rw-------  1 luis luis    0 oct 29 21:20  tmppj_aqsy7
# 1582410 -rw-------  1 luis luis    0 oct 29 21:06  tmppkqqc56_
# 1582453 -rw-------  1 luis luis    0 oct 29 21:09  tmppmmhcl7e
# 1582179 -rw-------  1 luis luis    0 oct 29 21:00  tmppn1glgfq
# 1583468 -rw-------  1 luis luis    0 oct 29 21:15  tmppqo7awa1
# 1583671 -rw-------  1 luis luis    0 oct 29 21:29  tmpprn5r348
# 1583677 -rw-------  1 luis luis    0 oct 29 21:29  tmppvbheels
# 1583559 -rw-------  1 luis luis    0 oct 29 21:21  tmp_pxe2kvd
# 1583982 -rw-------  1 luis luis    0 oct 29 21:48  tmppxecpdel
# 1583618 -rw-------  1 luis luis    0 oct 29 21:25  tmppyw_2eke
# 1582131 -rw-------  1 luis luis    0 oct 29 20:57  tmppzmtrzvi
# 1584018 -rw-------  1 luis luis    0 oct 29 21:50  tmpq3ex78cg
# 1583917 -rw-------  1 luis luis    0 oct 29 21:43  tmpq4gsmogz
# 1583607 -rw-------  1 luis luis    0 oct 29 21:25  tmpq5465rm8
# 1582192 -rw-------  1 luis luis    0 oct 29 21:01  tmpq6e9kb1v
# 1583449 -rw-------  1 luis luis    0 oct 29 21:14  tmpq99kj6iq
# 1583676 -rw-------  1 luis luis    0 oct 29 21:29  tmpq9o94ijx
# 1583476 -rw-------  1 luis luis    0 oct 29 21:16  tmpqax96fhs
# 1582095 -rw-------  1 luis luis    0 oct 29 20:55  tmpqcmaaxsf
# 1583517 -rw-------  1 luis luis    0 oct 29 21:18  tmpqdxamx0f
# 1582412 -rw-------  1 luis luis    0 oct 29 21:06  tmpqe5bwq3j
# 1582109 -rw-------  1 luis luis    0 oct 29 20:56  tmpqergups1
# 1583827 -rw-------  1 luis luis    0 oct 29 21:38  tmpqg80rlmn
# 1583911 -rw-------  1 luis luis    0 oct 29 21:43  tmpqgfib5r4
# ...
# 1583396 -rw-------  1 luis luis    0 oct 29 21:10  tmprk5h5m4l
# 1583793 -rw-------  1 luis luis    0 oct 29 21:35  tmprmjide25
# 1582190 -rw-------  1 luis luis    0 oct 29 21:01  tmprnubbgzq
# 1582165 -rw-------  1 luis luis    0 oct 29 20:59  tmprph5dsnt
# 1580817 -rw-------  1 luis luis    0 oct 29 20:51  tmprqvnbcth
# 1575123 -rw-------  1 luis luis    0 oct 29 20:47  tmprrf7_aym
# 1583935 -rw-------  1 luis luis    0 oct 29 21:45  tmprr_j2kd6
# 1582154 -rw-------  1 luis luis    0 oct 29 20:59  tmprrt_g24o
# 1582456 -rw-------  1 luis luis    0 oct 29 21:09  tmprrxx2bs9
# 1583713 -rw-------  1 luis luis    0 oct 29 21:31  tmpructvdbv
# 1583737 -rw-------  1 luis luis    0 oct 29 21:33  tmpruksy0gg
# 1583642 -rw-------  1 luis luis    0 oct 29 21:27  tmprvdbf6jn
# 1582448 -rw-------  1 luis luis    0 oct 29 21:09  tmprwz7wet0
# 1575061 -rw-------  1 luis luis    0 oct 29 20:45  tmprxq_d_md
# 1583553 -rw-------  1 luis luis    0 oct 29 21:21  tmpryaaenka
# 1583505 -rw-------  1 luis luis    0 oct 29 21:18  tmprz5xq0q1
# 1582114 -rw-------  1 luis luis    0 oct 29 20:56  tmprz7u83a6
# 1583689 -rw-------  1 luis luis    0 oct 29 21:30  tmps22lt9lk
# 1583597 -rw-------  1 luis luis    0 oct 29 21:24  tmps2kh_rpe
# 1583999 -rw-------  1 luis luis    0 oct 29 21:49  tmps4hoztgl
# 1582148 -rw-------  1 luis luis    0 oct 29 20:58  tmps4hqi60a
# 1583514 -rw-------  1 luis luis    0 oct 29 21:18  tmps4nlibd0
# 1577657 -rw-------  1 luis luis    0 oct 29 20:48  tmps4ueawmw
# 1583616 -rw-------  1 luis luis    0 oct 29 21:25  tmps5talfbn
# 1580950 -rw-------  1 luis luis    0 oct 29 20:53  tmps5uffodn
# 1582172 -rw-------  1 luis luis    0 oct 29 21:00  tmps9bdws_x
# 1580805 -rw-------  1 luis luis    0 oct 29 20:51  tmpsb24lw5x
# 1583524 -rw-------  1 luis luis    0 oct 29 21:19  tmpsc_1sq4x
# 1583732 -rw-------  1 luis luis    0 oct 29 21:33  tmpsevpawmc
# 1575152 -rw-------  1 luis luis    0 oct 29 20:47  tmpsg0fq1ob
# 1583728 -rw-------  1 luis luis    0 oct 29 21:33  tmpsh39wn0g
# 1583938 -rw-------  1 luis luis    0 oct 29 21:45  tmpshlvw1wj
# 1582222 -rw-------  1 luis luis    0 oct 29 21:03  tmpsihskmcz
# 1582139 -rw-------  1 luis luis    0 oct 29 20:58  tmpsj8tt_0w
# 1583518 -rw-------  1 luis luis    0 oct 29 21:18  tmpskc190h9
# 1583898 -rw-------  1 luis luis    0 oct 29 21:42  tmpskccc2l7
# 1584035 -rw-------  1 luis luis    0 oct 29 21:51  tmpskm5qwu5
# 1575070 -rw-------  1 luis luis    0 oct 29 20:45  tmpslgw3vi0
# 1584033 -rw-------  1 luis luis    0 oct 29 21:51  tmpsmcirmho
# 1583471 -rw-------  1 luis luis    0 oct 29 21:15  tmpsov7164n
# 1583567 -rw-------  1 luis luis    0 oct 29 21:22  tmpsra_2neg
# 1584000 -rw-------  1 luis luis    0 oct 29 21:49  tmpsskqkdf4
# 1583624 -rw-------  1 luis luis    0 oct 29 21:26  tmpst4o8t10
# 1583811 -rw-------  1 luis luis    0 oct 29 21:37  tmpsv54i6e0
# 1583833 -rw-------  1 luis luis    0 oct 29 21:38  tmpsvm9a1p7
# 1583528 -rw-------  1 luis luis    0 oct 29 21:19  tmpsxievwbf
# 1582108 -rw-------  1 luis luis    0 oct 29 20:56  tmpsys2nloq
# 1575059 -rw-------  1 luis luis    0 oct 29 20:45  tmpt246bh7w
# 1584017 -rw-------  1 luis luis    0 oct 29 21:50  tmpt2nyjde3
# 1583408 -rw-------  1 luis luis    0 oct 29 21:11  tmpt2y_wfaw
# 1583539 -rw-------  1 luis luis    0 oct 29 21:20  tmpt6794f6l
# 1583669 -rw-------  1 luis luis    0 oct 29 21:29  tmpt8vsonyt
# 1582215 -rw-------  1 luis luis    0 oct 29 21:03  tmptagskhl_
# 1583841 -rw-------  1 luis luis    0 oct 29 21:38  tmptas4qljm
# 1583779 -rw-------  1 luis luis    0 oct 29 21:34  tmptau6qkwy
# 1580940 -rw-------  1 luis luis    0 oct 29 20:53  tmptb79re49
# 1583386 -rw-------  1 luis luis    0 oct 29 21:10  tmptb9_pt_0
# 1583857 -rw-------  1 luis luis    0 oct 29 21:39  tmptc6kp0gm
# 1582421 -rw-------  1 luis luis    0 oct 29 21:07  tmptd202rmq
# 1583828 -rw-------  1 luis luis    0 oct 29 21:38  tmpt_dwexc8
# 1583990 -rw-------  1 luis luis    0 oct 29 21:48  tmptehi9p4j
# 1583609 -rw-------  1 luis luis    0 oct 29 21:25  tmptexi_vtn
# 1583499 -rw-------  1 luis luis    0 oct 29 21:17  tmptf1q0y42
# 1583963 -rw-------  1 luis luis    0 oct 29 21:47  tmptf23l9a4
# 1583882 -rw-------  1 luis luis    0 oct 29 21:41  tmpt_fn1nrj
# 1583474 -rw-------  1 luis luis    0 oct 29 21:15  tmptfrma6iv
# 1583829 -rw-------  1 luis luis    0 oct 29 21:38  tmptgm8foch
# 1577658 -rw-------  1 luis luis    0 oct 29 20:48  tmptgxz60fz
# 1583422 -rw-------  1 luis luis    0 oct 29 21:12  tmptgywhvo7
# 1584008 -rw-------  1 luis luis    0 oct 29 21:50  tmpth5ypjm4
# 1583799 -rw-------  1 luis luis    0 oct 29 21:36  tmpt_h95iau
# 1583442 -rw-------  1 luis luis    0 oct 29 21:13  tmptk1yhd7o
# 1580784 -rw-------  1 luis luis    0 oct 29 20:50  tmptkvaa1nc
# 1582216 -rw-------  1 luis luis    0 oct 29 21:03  tmptlvjd18f
# 1580793 -rw-------  1 luis luis    0 oct 29 20:50  tmptmzlpwz2
# 1583498 -rw-------  1 luis luis    0 oct 29 21:17  tmpt_o83yad
# 1583958 -rw-------  1 luis luis    0 oct 29 21:46  tmptpv2o5a1
# 1583433 -rw-------  1 luis luis    0 oct 29 21:13  tmptrcu0d2d
# 1583463 -rw-------  1 luis luis    0 oct 29 21:15  tmptrfbd9c2
# 1582252 -rw-------  1 luis luis    0 oct 29 21:05  tmpttdv7h61
# 1583892 -rw-------  1 luis luis    0 oct 29 21:42  tmptwwnqxlo
# 1583614 -rw-------  1 luis luis    0 oct 29 21:25  tmptxjq9j6i
# 1583926 -rw-------  1 luis luis    0 oct 29 21:44  tmpty8z1n01
# 1583416 -rw-------  1 luis luis    0 oct 29 21:12  tmptyj41l4j
# 1583791 -rw-------  1 luis luis    0 oct 29 21:35  tmptz1r40e9
# 1583682 -rw-------  1 luis luis    0 oct 29 21:29  tmpu195u2ww
# 1582085 -rw-------  1 luis luis    0 oct 29 20:54  tmpu3h7rl9r
# 1577659 -rw-------  1 luis luis    0 oct 29 20:48  tmpu5336fzy
# 1583771 -rw-------  1 luis luis    0 oct 29 21:34  tmpu7j_91v2
# 1580818 -rw-------  1 luis luis    0 oct 29 20:51  tmpu_8nzug6
# 1582183 -rw-------  1 luis luis    0 oct 29 21:01  tmpu8obi22k
# 1582408 -rw-------  1 luis luis    0 oct 29 21:06  tmpuctqt9xz
# 1575125 -rw-------  1 luis luis    0 oct 29 20:47  tmpudjisdlq
# 1583415 -rw-------  1 luis luis    0 oct 29 21:12  tmpuery5mog
# 1582113 -rw-------  1 luis luis    0 oct 29 20:56  tmpug6htux8
# 1582435 -rw-------  1 luis luis    0 oct 29 21:08  tmpugvhyqxe
# 1580826 -rw-------  1 luis luis    0 oct 29 20:52  tmpuhlo1m8n
# 1583546 -rw-------  1 luis luis    0 oct 29 21:20  tmpuk_ah0hz
# 1583443 -rw-------  1 luis luis    0 oct 29 21:14  tmpulnb2k5z
# 1582208 -rw-------  1 luis luis    0 oct 29 21:02  tmpum1ks7qx
# 1583502 -rw-------  1 luis luis    0 oct 29 21:17  tmpumskbw4k
# 1575164 -rw-------  1 luis luis    0 oct 29 20:48  tmpupbo68ff
# 1583507 -rw-------  1 luis luis    0 oct 29 21:18  tmpupv4zhwm
# 1583694 -rw-------  1 luis luis    0 oct 29 21:30  tmpupz2n9eh
# 1583548 -rw-------  1 luis luis    0 oct 29 21:21  tmpurilylyj
# 1583410 -rw-------  1 luis luis    0 oct 29 21:11  tmpuu6voosg
# 1582381 -rw-------  1 luis luis    0 oct 29 21:06  tmpuv3mceo9
# 1584030 -rw-------  1 luis luis    0 oct 29 21:51  tmpuvcjnya7
# 1583645 -rw-------  1 luis luis    0 oct 29 21:27  tmpuvhvwx4g
# 1582251 -rw-------  1 luis luis    0 oct 29 21:05  tmp_uvqryk0
# 1583409 -rw-------  1 luis luis    0 oct 29 21:11  tmpuwilv6j1
# 1583923 -rw-------  1 luis luis    0 oct 29 21:44  tmpuwyfyqjw
# 1580791 -rw-------  1 luis luis    0 oct 29 20:50  tmpux0_ucvp
# 1583467 -rw-------  1 luis luis    0 oct 29 21:15  tmpux77yjl1
# 1583453 -rw-------  1 luis luis    0 oct 29 21:14  tmpuy577dvx
# 1580807 -rw-------  1 luis luis    0 oct 29 20:51  tmpuy98tb7x
# 1577660 -rw-------  1 luis luis    0 oct 29 20:48  tmpv09xmgz_
# 1583789 -rw-------  1 luis luis    0 oct 29 21:35  tmpv0fjwtar
# 1583525 -rw-------  1 luis luis    0 oct 29 21:19  tmpv0y2h8yt
# 1580802 -rw-------  1 luis luis    0 oct 29 20:50  tmpv2p9jzqj
# 1583727 -rw-------  1 luis luis    0 oct 29 21:33  tmpv33evpq4
# 1582427 -rw-------  1 luis luis    0 oct 29 21:07  tmpv3qkuimu
# 1583819 -rw-------  1 luis luis    0 oct 29 21:37  tmpv3v3v1c1
# 1583586 -rw-------  1 luis luis    0 oct 29 21:23  tmpvamhet5e
# 1583630 -rw-------  1 luis luis    0 oct 29 21:26  tmpvcdfrybs
# 1583985 -rw-------  1 luis luis    0 oct 29 21:48  tmpvflxh2z5
# 1582454 -rw-------  1 luis luis    0 oct 29 21:09  tmpvgu_ut13
# 1580767 -rw-------  1 luis luis    0 oct 29 20:49  tmpvhtrza_x
# 1583994 -rw-------  1 luis luis    0 oct 29 21:49  tmpvi1yxkwq
# 1583925 -rw-------  1 luis luis    0 oct 29 21:44  tmpvjvarvah
# 1580956 -rw-------  1 luis luis    0 oct 29 20:53  tmpvkue2l2v
# 1578123 -rw-------  1 luis luis    0 oct 29 20:49  tmpvo_to5ds
# 1582425 -rw-------  1 luis luis    0 oct 29 21:07  tmpvs9fa8oc
# 1582162 -rw-------  1 luis luis    0 oct 29 20:59  tmpvt674000
# 1583575 -rw-------  1 luis luis    0 oct 29 21:22  tmpvx1j07rw
# 1580828 -rw-------  1 luis luis    0 oct 29 20:52  tmpvx3gc3m_
# 1582118 -rw-------  1 luis luis    0 oct 29 20:56  tmpvxho908v
# 1580959 -rw-------  1 luis luis    0 oct 29 20:53  tmpvzhyvi42
# 1583585 -rw-------  1 luis luis    0 oct 29 21:23  tmpvzquc693
# 1582177 -rw-------  1 luis luis    0 oct 29 21:00  tmpw0eaand6
# 1583794 -rw-------  1 luis luis    0 oct 29 21:35  tmpw1h1uc0h
# 1583451 -rw-------  1 luis luis    0 oct 29 21:14  tmpw287rzbs
# 1580812 -rw-------  1 luis luis    0 oct 29 20:51  tmpw2_f2o0n
# 1583427 -rw-------  1 luis luis    0 oct 29 21:13  tmpw3pfwkm1
# 1583610 -rw-------  1 luis luis    0 oct 29 21:25  tmpw42svu2t
# 1583843 -rw-------  1 luis luis    0 oct 29 21:39  tmpw5xe2728
# 1582128 -rw-------  1 luis luis    0 oct 29 20:57  tmpw96yjj5m
# 1583995 -rw-------  1 luis luis    0 oct 29 21:49  tmpw9yzmuxh
# 1582150 -rw-------  1 luis luis    0 oct 29 20:58  tmpwa0a7hy2
# 1583839 -rw-------  1 luis luis    0 oct 29 21:38  tmpwb75rx3t
# 1583659 -rw-------  1 luis luis    0 oct 29 21:28  tmpwbw__1zd
# 1583864 -rw-------  1 luis luis    0 oct 29 21:40  tmpwcw1s9y6
# 1582247 -rw-------  1 luis luis    0 oct 29 21:05  tmpwdty4zdi
# 1583636 -rw-------  1 luis luis    0 oct 29 21:26  tmpwfhhuj7h
# 1582157 -rw-------  1 luis luis    0 oct 29 20:59  tmpwhr4_qqi
# 1583522 -rw-------  1 luis luis    0 oct 29 21:19  tmpwix7e434
# 1583887 -rw-------  1 luis luis    0 oct 29 21:42  tmpwk4prfk4
# 1582233 -rw-------  1 luis luis    0 oct 29 21:04  tmpwlk22c5u
# 1583971 -rw-------  1 luis luis    0 oct 29 21:47  tmpw_n68um8
# 1583681 -rw-------  1 luis luis    0 oct 29 21:29  tmpwo1bs50d
# 1583426 -rw-------  1 luis luis    0 oct 29 21:12  tmpwpebn_y1
# 1583395 -rw-------  1 luis luis    0 oct 29 21:10  tmpwq8p0vip
# 1582201 -rw-------  1 luis luis    0 oct 29 21:02  tmpwqq7gfp3
# 1582231 -rw-------  1 luis luis    0 oct 29 21:04  tmpwqvz9yx3
# 1580822 -rw-------  1 luis luis    0 oct 29 20:52  tmpw_veih_v
# 1583603 -rw-------  1 luis luis    0 oct 29 21:24  tmpwvhnu2m0
# 1583993 -rw-------  1 luis luis    0 oct 29 21:49  tmpwvu43jbq
# 1583491 -rw-------  1 luis luis    0 oct 29 21:17  tmpwxt4ipm1
# 1583986 -rw-------  1 luis luis    0 oct 29 21:48  tmpwxwyl1_2
# 1583717 -rw-------  1 luis luis    0 oct 29 21:32  tmpwydpjv3g
# 1582219 -rw-------  1 luis luis    0 oct 29 21:03  tmpwy_kpm14
# 1583884 -rw-------  1 luis luis    0 oct 29 21:41  tmpx188h4xx
# 1583511 -rw-------  1 luis luis    0 oct 29 21:18  tmpx19joz14
# 1580949 -rw-------  1 luis luis    0 oct 29 20:53  tmpx2hnd05w
# 1583455 -rw-------  1 luis luis    0 oct 29 21:14  tmpx2x9y0on
# 1583543 -rw-------  1 luis luis    0 oct 29 21:20  tmpx5s12qpa
# 1583873 -rw-------  1 luis luis    0 oct 29 21:41  tmpx5thwewb
# 1583942 -rw-------  1 luis luis    0 oct 29 21:45  tmp_x75ynzk
# 1583795 -rw-------  1 luis luis    0 oct 29 21:35  tmpx9ec0tj2
# 1583581 -rw-------  1 luis luis    0 oct 29 21:23  tmpxaud46g1
# 1583975 -rw-------  1 luis luis    0 oct 29 21:47  tmp_xb4ht6k
# 1583805 -rw-------  1 luis luis    0 oct 29 21:36  tmpxcfi_e2w
# 1584005 -rw-------  1 luis luis    0 oct 29 21:49  tmpxfbtz3ae
# 1583820 -rw-------  1 luis luis    0 oct 29 21:37  tmpxff5a3ob
# 1582241 -rw-------  1 luis luis    0 oct 29 21:05  tmpxgn28wrc
# 1583883 -rw-------  1 luis luis    0 oct 29 21:41  tmpxlf3mf_o
# 1583394 -rw-------  1 luis luis    0 oct 29 21:10  tmpxm4k0ld7
# 1582200 -rw-------  1 luis luis    0 oct 29 21:02  tmpxmbhfk5y
# 1575099 -rw-------  1 luis luis    0 oct 29 20:46  tmpxorg2dhu
# 1582235 -rw-------  1 luis luis    0 oct 29 21:04  tmpxqxtjq1m
# 1575062 -rw-------  1 luis luis    0 oct 29 20:45  tmpxrovjrga
# 1583865 -rw-------  1 luis luis    0 oct 29 21:40  tmpxt2o2tqu
# 1582416 -rw-------  1 luis luis    0 oct 29 21:06  tmp_xzx0z84
# 1583774 -rw-------  1 luis luis    0 oct 29 21:34  tmpy4_666jz
# 1583627 -rw-------  1 luis luis    0 oct 29 21:26  tmpy71k7z86
# 1583666 -rw-------  1 luis luis    0 oct 29 21:28  tmpy7c6vyyl
# 1583484 -rw-------  1 luis luis    0 oct 29 21:16  tmpy88r6hgh
# 1583815 -rw-------  1 luis luis    0 oct 29 21:37  tmpy8v5_6lt
# 1583947 -rw-------  1 luis luis    0 oct 29 21:46  tmpy9dkzz9i
# 1580816 -rw-------  1 luis luis    0 oct 29 20:51  tmpyaepjixg
# 1583710 -rw-------  1 luis luis    0 oct 29 21:31  tmpyeu4vhm3
# 1582134 -rw-------  1 luis luis    0 oct 29 20:57  tmpyhb0tpx9
# 1582086 -rw-------  1 luis luis    0 oct 29 20:54  tmpyil2i3be
# 1580938 -rw-------  1 luis luis    0 oct 29 20:53  tmpyju1oh3u
# 1575066 -rw-------  1 luis luis    0 oct 29 20:45  tmpyk9qw5mo
# 1583928 -rw-------  1 luis luis    0 oct 29 21:44  tmpy_r86cgt
# 1582419 -rw-------  1 luis luis    0 oct 29 21:07  tmpys326baf
# 1575094 -rw-------  1 luis luis    0 oct 29 20:46  tmpytjttafl
# 1583956 -rw-------  1 luis luis    0 oct 29 21:46  tmpy_uyn7gf
# 1583383 -rw-------  1 luis luis    0 oct 29 21:10  tmpyvc7ycct
# 1575147 -rw-------  1 luis luis    0 oct 29 20:47  tmpyvnve81u
# 1583868 -rw-------  1 luis luis    0 oct 29 21:40  tmpywsm2g9q
# 1583869 -rw-------  1 luis luis    0 oct 29 21:40  tmpywzb5qdh
# 1583704 -rw-------  1 luis luis    0 oct 29 21:31  tmpyy0663sk
# 1582117 -rw-------  1 luis luis    0 oct 29 20:56  tmpyzdbmoxi
# 1583849 -rw-------  1 luis luis    0 oct 29 21:39  tmpz0a2m8mv
# 1582409 -rw-------  1 luis luis    0 oct 29 21:06  tmpz0nyeg40
# 1582129 -rw-------  1 luis luis    0 oct 29 20:57  tmpz0o4bnm3
# 1575133 -rw-------  1 luis luis    0 oct 29 20:47  tmpz14_zm3y
# 1583398 -rw-------  1 luis luis    0 oct 29 21:10  tmpz1_e__yv
# 1583808 -rw-------  1 luis luis    0 oct 29 21:36  tmpz2iym5dg
# 1580813 -rw-------  1 luis luis    0 oct 29 20:51  tmpz3_7h5oo
# 1583611 -rw-------  1 luis luis    0 oct 29 21:25  tmpz3_e5hod
# 1582138 -rw-------  1 luis luis    0 oct 29 20:58  tmpz3grsfls
# 1582127 -rw-------  1 luis luis    0 oct 29 20:57  tmpz5ht7g1u
# 1583572 -rw-------  1 luis luis    0 oct 29 21:22  tmpz6viyb40
# 1580955 -rw-------  1 luis luis    0 oct 29 20:53  tmpz8hbe7qn
# 1582405 -rw-------  1 luis luis    0 oct 29 21:06  tmpz8r7fo7u
# 1582137 -rw-------  1 luis luis    0 oct 29 20:58  tmpzb3i2kdi
# 1580960 -rw-------  1 luis luis    0 oct 29 20:54  tmpzd2q51e_
# 1582132 -rw-------  1 luis luis    0 oct 29 20:57  tmpzgrmdi8l
# 1582439 -rw-------  1 luis luis    0 oct 29 21:08  tmpzh19qzoh
# 1582100 -rw-------  1 luis luis    0 oct 29 20:55  tmp_zhprnw6
# 1583621 -rw-------  1 luis luis    0 oct 29 21:25  tmpzi8qdlj9
# 1582220 -rw-------  1 luis luis    0 oct 29 21:03  tmpzj5670l2
# 1582209 -rw-------  1 luis luis    0 oct 29 21:02  tmpzk1xxaf7
# 1580803 -rw-------  1 luis luis    0 oct 29 20:51  tmpzlfbp98v
# 1583419 -rw-------  1 luis luis    0 oct 29 21:12  tmpzlz4dqwm
# 1583798 -rw-------  1 luis luis    0 oct 29 21:35  tmpzmf2cxzt
# 1580790 -rw-------  1 luis luis    0 oct 29 20:50  tmpzmjpimpf
# 1583837 -rw-------  1 luis luis    0 oct 29 21:38  tmpznfusv5k
# 1583777 -rw-------  1 luis luis    0 oct 29 21:34  tmpzo4p1ov9
# 1583461 -rw-------  1 luis luis    0 oct 29 21:15  tmpzoga4_ab
# 1582432 -rw-------  1 luis luis    0 oct 29 21:07  tmpzpi75sfq
# 1580779 -rw-------  1 luis luis    0 oct 29 20:49  tmpzq2zd5xv
# 1583930 -rw-------  1 luis luis    0 oct 29 21:44  tmpzr448m9f
# 1582080 -rw-------  1 luis luis    0 oct 29 20:54  tmpzuls9azi
# 1579823 -rw-------  1 luis luis    0 oct 29 20:49  tmpzwfuo247
# 1583909 -rw-------  1 luis luis    0 oct 29 21:43  tmpzw__la38
# 1573204 -rw-------  1 luis luis  954 oct 29 12:01  .touchpaddefaults
# 1572866 drwxrwxrwt  2 root root 4.0K oct 29 12:01  .X11-unix
# 1573199 -rw-------  1 luis luis  108 oct 29 12:01  xauth-1000-_0
# 1572868 drwxrwxrwt  2 root root 4.0K oct 29 12:01  .XIM-unix

# %%
rm -r /tmp/dir1

# %%
mkdir -p /tmp/dir1
tree /tmp/dir1
echo -e "\n---------\n"
echo -e "enlace duro de /tmp/dir1  y /tmp dentro de /tmp/dir1\n."
ls -ilhaR /tmp/dir1
# Out:
# /tmp/dir1
#
# 0 directories, 0 files
#
# ---------
#
# enlace duro de /tmp/dir1  y /tmp dentro de /tmp/dir1
# .
# /tmp/dir1:
# total 76K
# 1573196 drwxrwxr-x  2 luis luis 4.0K oct 30 01:55 .
# 1572865 drwxrwxrwt 27 root root  68K oct 30 01:55 ..

# %%
# Los inodos de /tmp y de /tmp/dir
echo -e "\nenlace duro de /tmp dentro de /."
ls -i / | grep tmp
echo -e "\nenlace duro de /tmp/dir1 dentro de /tmp."
ls -i /tmp | grep dir1
# Out:
# enlace duro de /tmp dentro de /.
# 1572865 tmp
#
# enlace duro de /tmp/dir1 dentro de /tmp.
# 1573196 dir1

# %%
mkdir /tmp/dir1/dir2 /tmp/dir1/dir3

tree /tmp/dir1
echo -e "\n---------\n"
ls -ilhaR /tmp/dir1
# Out:
# /tmp/dir1
# ├── dir2
# └── dir3
#
# 2 directories, 0 files
#
# ---------
#
# /tmp/dir1:
# total 84K
# 1573196 drwxrwxr-x  4 luis luis 4.0K oct 30 01:55 .
# 1572865 drwxrwxrwt 27 root root  68K oct 30 01:55 ..
# 1584019 drwxrwxr-x  2 luis luis 4.0K oct 30 01:55 dir2
# 1584020 drwxrwxr-x  2 luis luis 4.0K oct 30 01:55 dir3
#
# /tmp/dir1/dir2:
# total 8.0K
# 1584019 drwxrwxr-x 2 luis luis 4.0K oct 30 01:55 .
# 1573196 drwxrwxr-x 4 luis luis 4.0K oct 30 01:55 ..
#
# /tmp/dir1/dir3:
# total 8.0K
# 1584020 drwxrwxr-x 2 luis luis 4.0K oct 30 01:55 .
# 1573196 drwxrwxr-x 4 luis luis 4.0K oct 30 01:55 ..

# %%
echo "contenido inicial archivo 1" > /tmp/dir1/dir2/arc1
tree /tmp/dir1
ls -ilhaR /tmp/dir1
# Out:
# /tmp/dir1
# ├── dir2
# │   └── arc1
# └── dir3
#
# 2 directories, 1 file
# /tmp/dir1:
# total 84K
# 1573196 drwxrwxr-x  4 luis luis 4.0K oct 30 01:55 .
# 1572865 drwxrwxrwt 27 root root  68K oct 30 01:55 ..
# 1584019 drwxrwxr-x  2 luis luis 4.0K oct 30 01:55 dir2
# 1584020 drwxrwxr-x  2 luis luis 4.0K oct 30 01:55 dir3
#
# /tmp/dir1/dir2:
# total 12K
# 1584019 drwxrwxr-x 2 luis luis 4.0K oct 30 01:55 .
# 1573196 drwxrwxr-x 4 luis luis 4.0K oct 30 01:55 ..
# 1584021 -rw-rw-r-- 1 luis luis   28 oct 30 01:55 arc1
#
# /tmp/dir1/dir3:
# total 8.0K
# 1584020 drwxrwxr-x 2 luis luis 4.0K oct 30 01:55 .
# 1573196 drwxrwxr-x 4 luis luis 4.0K oct 30 01:55 ..

# %%
ln /tmp/dir1/dir2/arc1 /tmp/dir1/dir2/arc1-hl1
ln /tmp/dir1/dir2/arc1 /tmp/dir1/dir3/arc1
ln -s /tmp/dir1/dir2/arc1 /tmp/dir1/dir3/arc1-sl
tree /tmp/dir1
# Out:
# /tmp/dir1
# ├── dir2
# │   ├── arc1
# │   └── arc1-hl1
# └── dir3
#     ├── arc1
#     └── arc1-sl -> /tmp/dir1/dir2/arc1
#
# 2 directories, 4 files

# %%
chmod +x /tmp/dir1/dir2/arc1-hl1

# %%
ls -ilhaR /tmp/dir1
# Out:
# /tmp/dir1:
# total 84K
# 1573196 drwxrwxr-x  4 luis luis 4.0K oct 30 01:55 .
# 1572865 drwxrwxrwt 27 root root  68K oct 30 01:55 ..
# 1584019 drwxrwxr-x  2 luis luis 4.0K oct 30 01:55 dir2
# 1584020 drwxrwxr-x  2 luis luis 4.0K oct 30 01:55 dir3
#
# /tmp/dir1/dir2:
# total 16K
# 1584019 drwxrwxr-x 2 luis luis 4.0K oct 30 01:55 .
# 1573196 drwxrwxr-x 4 luis luis 4.0K oct 30 01:55 ..
# 1584021 -rwxrwxr-x 3 luis luis   28 oct 30 01:55 arc1
# 1584021 -rwxrwxr-x 3 luis luis   28 oct 30 01:55 arc1-hl1
#
# /tmp/dir1/dir3:
# total 12K
# 1584020 drwxrwxr-x 2 luis luis 4.0K oct 30 01:55 .
# 1573196 drwxrwxr-x 4 luis luis 4.0K oct 30 01:55 ..
# 1584021 -rwxrwxr-x 3 luis luis   28 oct 30 01:55 arc1
# 1584048 lrwxrwxrwx 1 luis luis   19 oct 30 01:55 arc1-sl -> /tmp/dir1/dir2/arc1

# %%
find /tmp/dir1 -samefile "/tmp/dir1/dir2/arc1"
# Out:
# /tmp/dir1/dir3/arc1
# /tmp/dir1/dir2/arc1-hl1
# /tmp/dir1/dir2/arc1

# %%
find -L /tmp/dir1 -samefile "/tmp/dir1/dir2/arc1"
# Out:
# /tmp/dir1/dir3/arc1
# /tmp/dir1/dir3/arc1-sl
# /tmp/dir1/dir2/arc1-hl1
# /tmp/dir1/dir2/arc1

# %%
echo "añadido desde /tmp/dir1/dir2/arc1-hl1" >> /tmp/dir1/dir2/arc1-hl1
echo "añadido desde /tmp/dir1/dir3/arc1-sl" >> /tmp/dir1/dir3/arc1-sl
echo "añadido desde /tmp/dir1/dir3/arc1" >> /tmp/dir1/dir3/arc1
cat /tmp/dir1/dir2/arc1
cat /tmp/dir1/dir2/arc1-hl1
cat /tmp/dir1/dir3/arc1-sl
cat /tmp/dir1/dir3/arc1
# Out:
# contenido inicial archivo 1
# añadido desde /tmp/dir1/dir2/arc1-hl1
# añadido desde /tmp/dir1/dir3/arc1-sl
# añadido desde /tmp/dir1/dir3/arc1
# contenido inicial archivo 1
# añadido desde /tmp/dir1/dir2/arc1-hl1
# añadido desde /tmp/dir1/dir3/arc1-sl
# añadido desde /tmp/dir1/dir3/arc1
# contenido inicial archivo 1
# añadido desde /tmp/dir1/dir2/arc1-hl1
# añadido desde /tmp/dir1/dir3/arc1-sl
# añadido desde /tmp/dir1/dir3/arc1
# contenido inicial archivo 1
# añadido desde /tmp/dir1/dir2/arc1-hl1
# añadido desde /tmp/dir1/dir3/arc1-sl
# añadido desde /tmp/dir1/dir3/arc1

# %%
rm /tmp/dir1/dir2/arc1
cat /tmp/dir1/dir2/arc1
cat /tmp/dir1/dir2/arc1-hl1
cat /tmp/dir1/dir3/arc1-sl
cat /tmp/dir1/dir3/arc1
# Out:
# cat: /tmp/dir1/dir2/arc1: No existe el archivo o el directorio
# contenido inicial archivo 1
# añadido desde /tmp/dir1/dir2/arc1-hl1
# añadido desde /tmp/dir1/dir3/arc1-sl
# añadido desde /tmp/dir1/dir3/arc1
# cat: /tmp/dir1/dir3/arc1-sl: No existe el archivo o el directorio
# contenido inicial archivo 1
# añadido desde /tmp/dir1/dir2/arc1-hl1
# añadido desde /tmp/dir1/dir3/arc1-sl
# añadido desde /tmp/dir1/dir3/arc1

# %%
ls -ilhaR /tmp/dir1
# Out:
# /tmp/dir1:
# total 84K
# 1584019 drwxrwxr-x  4 luis luis 4.0K oct 29 22:28 .
# 1572865 drwxrwxrwt 27 root root  68K oct 30 01:01 ..
# 1584020 drwxrwxr-x  2 luis luis 4.0K oct 30 01:45 dir2
# 1584021 drwxrwxr-x  2 luis luis 4.0K oct 30 01:31 dir3
#
# /tmp/dir1/dir2:
# total 12K
# 1584020 drwxrwxr-x 2 luis luis 4.0K oct 30 01:45 .
# 1584019 drwxrwxr-x 4 luis luis 4.0K oct 29 22:28 ..
# 1573196 -rwxrwxr-x 2 luis luis  140 oct 30 01:43 arc1-hl1
#
# /tmp/dir1/dir3:
# total 12K
# 1584021 drwxrwxr-x 2 luis luis 4.0K oct 30 01:31 .
# 1584019 drwxrwxr-x 4 luis luis 4.0K oct 29 22:28 ..
# 1573196 -rwxrwxr-x 2 luis luis  140 oct 30 01:43 arc1
# 1584048 lrwxrwxrwx 1 luis luis   19 oct 30 01:31 arc1-sl -> /tmp/dir1/dir2/arc1

# %% [markdown]
# ###### Enlaces simbólicos como alternativa a modificar la variable PATH

# %% [markdown]
# ```bash
# #Habilitar Julia para todos los usuarios.
# sudo ln -s /opt/julia/julia-1.5.2/bin/julia /usr/local/bin/julia
#
# #Para anaconda y Jupyter para todos los usuarios.
# sudo ln -s /opt/anaconda3/bin/anaconda-navigator /usr/local/bin/condanav
# sudo ln -s /opt/anaconda3/bin/conda /usr/local/bin/conda
# sudo ln -s /opt/anaconda3/bin/jupyter-notebook /usr/local/bin/jnote
#
# #Igual que los anteriores, pero sólo para el usuario actual.
# ln -s /opt/julia/julia-1.5.2/bin/julia ~/.local/bin/julia
# sudo ln -s /opt/anaconda3/bin/anaconda-navigator ~/.local/bin/condanav
# sudo ln -s /opt/anaconda3/bin/conda ~/.local/bin/conda
# sudo ln -s /opt/anaconda3/bin/jupyter-notebook ~/.local/bin/jnote
#
# #Eliminar los enlaces para todos los usuarios.
# sudo rm /usr/local/bin/julia
# sudo rm /usr/local/bin/condanav
# sudo rm /usr/local/bin/conda
# sudo rm /usr/local/bin/jnote
#
# #Eliminar los enlaces para el usuario actual.
# rm ~/.local/bin/julia
# rm ~/.local/bin/condanav
# rm ~/.local/bin/conda
# rm ~/.local/bin/jnote
# ```

# %% [markdown]
# #### Ejemplos de como se pueden ejecutar cálculos desde Bash con Maxima, Python y Julia

# %%
echo "a+a;" | maxima -q --very-quiet
# Out:
#                                       2 a

# %%
echo "print(1+1)" | python
# Out:
# 2

# %%
echo "println(1+1)" | julia
# Out:
# 2
